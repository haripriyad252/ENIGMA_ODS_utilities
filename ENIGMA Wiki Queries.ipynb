# %% [markdown]
# # <center>Querying the ENIGMA Wiki</center>

# %% [markdown]
# This notebook contains some sample queries to explore the data stored in the ENIGMA Wiki.

# %%
import json
import requests

# %%
url = "http://linkedearth.isi.edu:3030/db"

query = """PREFIX core: <https://knowledgecaptureanddiscovery.github.io/EnigmaOntology/release/>
PREFIX wiki: <http://organicdatacuration.org/enigma_new/index.php/Special:URIResolver>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT distinct ?a 
WHERE 
{
    # ?w rdfs:label ?a.
}"""


response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

print("All properties:")    
for item in res['results']['bindings']:
    print ("*" + item['a']['value'])
print(res)
# Out:
# All properties:
# *Foaf:knows
# *Pages with ignored display titles
# *Imported vocabulary
# *Has processing error
# *Modification date
# *Has property description
# *Has improper value for
# * IMPO
# *Has processing error text
# *Language code
# *Text
# *Foaf:name
# *Foaf:homepage
# *Owl:differentFrom
# *HasCity (E)
# *Has multiple values
# *True
# *HasConsortium
# *UsesDiagnosisInstrument (E)
# *Has page category
# *DiagnosisInstrument (E)
# *ObtainedInformationThrough (E)
# *InformationObtainmentMethod (E)
# *HasLocationOfDataCollection (E)
# *Location (E)
# *Has User ID
# *HasFirstAuthor
# *HasLastAuthor (E)
# *Hypothesis (E)
# *HasAuthorRulesPage (E)
# *HasFirstAuthor2 (E)
# *HasFirstAuthor (E)
# *Http://organicdatacuration.org/enigma new/index.php/Special:authorGeneration?project=ENIGMA3 Cortical GWAS
# *HasAuthorGenerationPage (E)
# *HasFirstDegreeRelativeWithDisorder (E)
# *Disorder (E)
# *HasFamilyHistoryOf (E)
# *HasDiagnosisInstrument (E)
# *HasDisorderDetails (E)
# *SpecificDisorderInfo (E)
# *DoesNotHaveFirstDegreeRelativeWithDisorder (E)
# *Disjoint with
# *DoesNotHaveFamilyHistoryOf (E)
# *UsesTreatment (E)
# *Treatment (E)
# *HasInformationMethod (E)
# *HasMembersWithRecentIssue (E)
# *Condition (E)
# *DoesNotUseTreatment (E)
# *HasPersonalHistoryOf (E)
# *DoesNotHaveDisorder (E)
# *HasDisorder (E)
# *UsesGenotypePlatform (E)
# *GenotypePlatform (E)
# *HasCondition (E)
# *HasFirstEpisodeOf (E)
# *HasTreatmentDetails (E)
# *SpecificTreatmentInfo (E)
# *DoesNotHaveCondition (E)
# *DidNotHaveFirstEpisodeOf (E)
# *DoesNotHavePersonalHistoryOf (E)
# *FulfillsDiagnosticCriteria (E)
# *DiagnosticCriteria (E)
# *HasMedicalRatingDetails (E)
# *SpecificMedicalRatingInfo (E)
# *DoesNotHaveIntellectualDisability (E)
# *WithMaxDurationOfDisorder (E)
# *WithMinDurationOfDisorder (E)
# *HasLongitudinalTimepoint (E)
# *IncludesFemale (E)
# *NewCategory (E)
# *HasHandedness (E)
# *DoesNotHavePsychiatricComorbidity (E)
# *HasPsychiatricComorbidity (E)
# *DoesNotHaveComorbidity (E)
# *IsClinicallyStable (E)
# *HasNumberOfCisFemale (E)
# *HasComorbidity (E)
# *IsProficientInLocalLanguage (E)
# *HasFamilialRelations (E)
# *HasNeurologicalComorbidity (E)
# *IsFamilyBased (E)
# *ExcludesRightHands (E)
# *HasMaxIQ (E)
# *HasNumberOfCisMale (E)
# *HasMinIQ (E)
# *WithMinNumber (E)
# *ExcludesLeftHands (E)
# *DoesNotHaveContraindicationToMRI (E)
# *WithDisorderSeverity (E)
# *WithMaxAgeOfOnsetOfDisorder (E)
# *WithMaxNumber (E)
# *HasSexDeterminedGenetically (E)
# *DoesNotHaveNeurologicalComorbidity (E)
# *HasBrainStructuralData (E)
# *HasNumberOfMale (E)
# *HasCohort (E)
# *Cohort (E)
# *HasWorkingGroupMember (E)
# *Person (E)
# *Foaf:Member (E)
# *UsedSoftware (E)
# *Software (E)
# *Contributor (E)
# *Dcterms:Contributor (E)
# *HasReviewer (E)
# *HasDiagnosticGroup (E)
# *CohortGroup (E)
# *HasCohortGroup (E)
# *HasMainPrincipalInvestigator (E)
# *HasPrincipalInvestigator (E)
# *HasDataCollector (E)
# *HasWorkingGroupChair (E)
# *Dcterms:IsPartOf (E)
# *HasInvestigator (E)
# *HasPublication (E)
# *AcademicArticle (E)
# *OrcidId (E)
# *Is defined by
# *Http://vivoweb.org/ontology/core
# *IsAcquisitionProtocolOf (E)
# *Foaf:Mbox (E)
# *Http://xmlns.com/foaf/0.1/
# *HasGeneticDataType (E)
# *GeneticDataType (E)
# *HasDataType (E)
# *ForDataType (E)
# *DataType (E)
# *HasAcquisitionDirection (E)
# *AcquisitionDirection (E)
# *HasSequence (E)
# *MRISequence (E)
# *HasGeneticDataCollector (E)
# *HasQualifiedAffiliation (E)
# *QualifiedAffiliation (E)
# *ForOrganization (E)
# *Foaf:Organization (E)
# *Schema:Distribution (E)
# *Schema:DataDownload (E)
# *HasProjectLead (E)
# *Foaf:Homepage (E)
# *HasDataAnalyst (E)
# *HasConflictOfInterest (E)
# *ConflictOfInterest (E)
# *HasDesigner (E)
# *HasDataset (E)
# *Dataset (E)
# *UsesProtocol (E)
# *Protocol (E)
# *HasImagingDataAnalyst (E)
# *HasContact (E)
# *HasEmail (E)
# *IsScannerOf (E)
# *AcquisitionProtocol (E)
# *HasProject (E)
# *Project (E)
# *HasStatistics (E)
# *HasImageAcquisitionProtocol (E)
# *ImageAcquisitionProtocol (E)
# *HasAffiliate (E)
# *HasGenotypeImputationProtocol (E)
# *GenotypeImputationProtocol (E)
# *UsesScannerSoftware (E)
# *ScannerSoftware (E)
# *HasHomePage (E)
# *HasGeneReferencePanel (E)
# *GeneReferencePanel (E)
# *HasOrcidId (E)
# *HasGeneticDataAnalyst (E)
# *RanProtocol (E)
# *HasImagingDataCollector (E)
# *IsPartOfOrganization (E)
# *Organization (E)
# *HasControlGroup (E)
# *HasPopulationGroup (E)
# *Author (E)
# *Dcterms:Creator (E)
# *HasBrainScanDataType (E)
# *BrainScanDataType (E)
# *HasLastProjectLead (E)
# *HasManufacturer (E)
# *Manufacturer (E)
# *HasDiagnosticInstrument (E)
# *DiagnosticInstrument (E)
# *HasAddress (E)
# *Address (E)
# *HasProtocolRunner (E)
# *HasPrimaryAddress (E)
# *FirstDraftContributor (E)
# *HasProjectCohort (E)
# *ProjectCohort (E)
# *ForPublication (E)
# *HasGeneticAssociationProtocol (E)
# *GeneticAssociationProtocol (E)
# *HasBriefDescription (E)
# *HasResolution (E)
# *HasStartDate (E)
# *Locality (E)
# *HasNumberOfT1w (E)
# *HasNumberOfT2 (E)
# *HasVenue (E)
# *HasFundingSource (E)
# *Street-address (E)
# *HasExclusionCriteria (E)
# *HasTE (E)
# *HasAgeGroup (E)
# *HasResearchInterest (E)
# *IsPublic (E)
# *FullName (E)
# *Dcterms:Title (E)
# *HasPercentExomeSequencing (E)
# *UsesScanner (E)
# *HasStudyFeature (E)
# *GivenName (E)
# *Foaf:GivenName (E)
# *HasPercentSelectLoci (E)
# *HasCategory (E)
# *HasPercentGeneExpression (E)
# *HasVersion (E)
# *HasMeanAge (E)
# *HasPercentGenomewideGenotyping (E)
# *HasDataAcquisitionMatrix (E)
# *Foaf:FamilyName (E)
# *HasLink (E)
# *HasTitle (E)
# *HasPercentOfMale (E)
# *HasPublishedPaper (E)
# *HasNumberOfUndisclosedGender (E)
# *HasGrant (E)
# *HasStudyDesign (E)
# *HasTargetDate (E)
# *Country-name (E)
# *Region (E)
# *HasAdditionalDemographic (E)
# *HasTI (E)
# *HasFieldStrength (E)
# *Dcterms:Spatial (E)
# *HasPercentPlasma (E)
# *HasCollectionSite (E)
# *HasArticleStatus (E)
# *HasNumberOfEEG (E)
# *HasNumberOfParticipants (E)
# *HasMemorandumOfUnderstanding (E)
# *HasPercentWholeGenomeSequencing (E)
# *HasDegree (E)
# *CurrentJobTitle (E)
# *HasPercentOfFemale (E)
# *HasPercentMitochondrialGenotyping (E)
# *HasMiddleInitial (E)
# *ShortName (E)
# *HasSpecies (E)
# *Dcterms:Identifier (E)
# *UsedBodyCoil (E)
# *HasName (E)
# *HasPregnantMembers (E)
# *HasEndDate (E)
# *Schema:Name (E)
# *HasNumberOfTransgenderFtoM (E)
# *HasNumberOfTransgenderMtoF (E)
# *HasPercentBloodSalivaCollection (E)
# *FamilyName (E)
# *HasNumberOftbfMRI (E)
# *Schema:ContentUrl (E)
# *HasNEX (E)
# *Postal-code (E)
# *IsScannerModel (E)
# *HasStatus (E)
# *HasCohortStatus (E)
# *Dcterms:Description (E)
# *HasSliceThickness (E)
# *HasNumberOfdMRI (E)
# *HasDescription (E)
# *Dcterms:Date (E)
# *HasEthnicGroup (E)
# *HasSubmittedPaper (E)
# *HasType (E)
# *HasFlipAngle (E)
# *HasVoxelSize (E)
# *HasMaximumAge (E)
# *Kind (E)
# *HasFoV (E)
# *HasNumberOfASL (E)
# *HasSliceOrientation (E)
# *HasAgeStandardDeviation (E)
# *HasDataCollectionPeriodStart (E)
# *HasDataCollectionPeriodEnd (E)
# *Schema:EncodingFormat (E)
# *HasTR (E)
# *HasSoftwareVersion (E)
# *UsedHeadCoil (E)
# *HasPercentEpigeneticsBlood (E)
# *HasScanTime (E)
# *HasApprovedProposalForm (E)
# *HasMinimumAge (E)
# *HasPercentDNAExtractionNoGenotyping (E)
# *HasNumberOfSWI (E)
# *HasPercentTranscriptomics (E)
# *Schema:Description (E)
# *HasNumberOfrsfMRI (E)
# *HasNumberOfSlices (E)
# *HasNumberOfEchoes (E)
# *HasPercentEpigeneticsSaliva (E)
# *HasOutputFeature (E)
# *HasProjectStatus (E)
# *AuthorRules:SZPositiveSymptoms
# *AMC
# *AMCControlGroup
# *AMCDiagnosticGroup
# *HasEnigmaContact (E)
# *Marise Machielsen
# *HasPI (E)
# *M.w.machielsen@amc.uva.nl
# *IsAffiliatedWith (E)
# *Imaging Genetics Centre
# *ASRB
# *ASRBControlGroup
# *ASRBDiagnosticGroup
# *Chris Pantelis
# *Melissa Green
# *Ulrich Shall
# *Paul Rasser
# *Vaughan Carr
# *Cpant@unimelb.edu.au
# *Melissa.green@unsw.edu.au
# *IsNoLongerActive (E)
# *F
# *Ulrich.schall@newcastle.edu.au
# *Paul.rasser@newcastle.edu.au
# *Priority centre for Brain and Mental Health
# *Department of Clinical Neuroscience, Psychiatry Section, Karolinska Institutet, Stockholm
# *NORMENT, KG Jebsen Centre for Psychosis Research, Oslo
# *Erlend S. Dørum
# *NORMENT - KG Jebsen Centre, Division of Mental Health and Addiction, University of Oslo
# *Sunnaas Rehabilitation Hospital HT
# *Department of Psychology, Oslo
# *Esther Walton
# *Walton
# *Waltonesther@gmail.com
# *University of California
# *F. Piras
# *Fabrice Crivello
# *University of Bordeaux
# *Fleur M. Howells
# *Department of Psychiatry, Cape Town
# *Fude Yang
# *PhD
# *Erasmus University Medical Centre
# *Gareth Barker
# *Centre for Neuroimaging Sciences, Institute of Psychiatry,
# *Gary Donohoe
# *Cognitive Genetics and Cognitive Therapy Group, National University Ireland, Galway
# *Department of Psychiatry, Trinity College
# *CAMH
# *CAMHControlGroup
# *CAMHDiagnosticGroup
# *Aristotle Voineskos
# *Gary Y
# *Greig I. de Zubicaray
# *Faculty of Health and Institute of Health and Biomedical Innovation
# *Aristotle.voineskos@camh.ca
# *CIAM
# *CIAMControlGroup
# *CIAMDiagnosticGroup
# *Anne Uhlmann
# *Dan Stein
# *Fleur Howells
# *Guillén Fernández
# *Department of Cognitive Neuroscience, Radboud University
# *Donders Institute for Brain, Radboud University
# *H. C. Whalley
# *Uhlmann
# *Uhlmann.aa@gmail.com
# *H. Yamamori
# *Stein
# *Jason stein@med.unc.edu
# *Hans J. Grab
# *Department of Psychiatry, Greifswald
# *Howellsfleur@gmail.com
# *CLING
# *HasAcquisitionProtocol (E)
# *CLING-IAP
# *T1-weightedMRI
# *CLINGControlGroup
# *CLINGDiagnosticGroup
# *O. Gruber
# *IncludesMale (E)
# *T
# *Hao Hu
# *Shanghai Mental Health Center, Shanghai
# *Harald Kugel
# *Department of Clinical Radiology, Münster
# *Henry Brodaty
# *Brodaty
# *H.brodaty@unsw.edu.au
# *Centre for Healthy Brain Ageing (CHeBA), & Dementia Collaborative Research Centre, School of Psychiatry, UNSW Medicine,
# *Oliver.Gruber@med.uni-heidelberg.de
# *COBRE
# *COBREControlGroup
# *COBREDiagnosticGroup
# *Jessica Turner
# *Vince D. Calhoun
# *Herta Flor
# *Flor
# *Herta.flor@zi-mannheim.de
# *Department of Cognitive and Clinical Neuroscience, Heidelberg University
# *Herve Lemaitre
# *Institut National de la Santé et de la Recherche Médicale, Paris
# *Turner
# *Jturner@mrn.org
# *University of Iowa
# *IsLocated (E)
# *Irvine, California
# *Hilleke E. Hulshoff Pol
# *Brain Centre Rudolf Magnus, University Medical Centre Utrecht
# *Vcalhoun@mrn.org
# *Departments of Electrical and Computer Engineering, University of New Mexico
# *The Mind Research Network, Albuquerque
# *DublinDonohoe
# *Dublin-IAP
# *DublinControlGroup
# *DublinDiagnosticGroup
# *G. Donohoe
# *Sinead Kelly
# *Hugh Garavan
# *Departments of Psychiatry and Psychology
# *I. Melle
# *Ian J. Deary
# *Centre for Cognitive Ageing and Cognitive Epidemiology, Psychology, University of Edinburgh
# *Gary.donhoe@nuigalway.edu
# *Imaging Genetics Center, Institute for Neuroimaging & Informatics, USC
# *Ignacio Martínez-Zalacaín
# *Department of Psychiatry, Barcelona
# *EdinburghEHRS
# *EdinburghEHRSControlGroup
# *EdinburghEHRSDiagnosticGroup
# *S. Lawrie
# *E. Neilson
# *Ingrid Agartz
# *Agartz
# *Ingrid.agartz@medisin.uio.no
# *NORMENT - KG Jebsen Centre, Institute of Clinical Medicine, University of Oslo
# *Department of Research and Development, Diakonhjemmet Hospital, Oslo
# *E.Neilson-3@sms.ed.ac.uk
# *Jan Buitelaar
# *Buitelaar
# *Jan.Buitelaar@radboudumc.nl
# *Department of Cognitive Neuroscience
# *Karakter Child and Adolescent Psychiatry, Raboud Universty
# *EdinburghFunc
# *EdinburghFuncControlGroup
# *EdinburghFuncDiagnosticGroup
# *Andrew McIntosh
# *Jean-Paul Fouche
# *Iowa
# *EdinburghSFMH
# *EdinburghSFMHControlGroup
# *EdinburghSFMHDiagnosticGroup
# *Jian Wenhao
# *Brain and Mind Centre, Sydney
# *John Blangero
# *Blangero
# *John.blangero@UTRGV.edu
# *Department of Genetics, Texas Biomedical Research Institute
# *South Texas Diabetes and Obesity Institute, University of Texas Rio Grande Valley School of Medicine
# *ESO
# *ESOControlGroup
# *ESODiagnosticGroup
# *Filip Spaniel
# *Cyril Hoschl
# *Department of Psychiatry & Behavioral Science, Seoul
# *Filip.Spaniel@nudz.cz
# *Institute of Human Behavioral Medicine, Seoul
# *Department of Brain & Cognitive Sciences, Seoul
# *FBIRN
# *FBIRNControlGroup
# *FBIRNDiagnosticGroup
# *S. G. Potkin
# *Theo G. M. vanErp
# *Van Erp Theo GM
# *Jürgen Gallinat
# *Department of Psychiatry and Psychotherapy
# *Ellernholzstrasse12MecklenburgVorpommern17489
# *Grabe Hans J
# *Hans Grabe
# *Tilo Kircher
# *Axel Krug
# *Bruno Dietsche
# *Andreas Jansen
# *RudolfBultmannStr835039
# *University of Greifswald
# *Philipps-University Marburg
# *K. N. Jorgensen
# *Karolinska Schizophrenia Project Consortium
# *Tvanerp@uci.edu
# *Department Of Psychiatry, Irvine
# *Klaus-Peter Lesch
# *Division of Molecular Psychiatry, Würzburg
# *Department of Translational Neuroscience, Maastricht
# *FIDMAG
# *FIDMAGControlGroup
# *FIDMAGDiagnosticGroup
# *Joaquim Radua
# *Edith Pomarol-Clotet
# *L. M. Beard
# *Jradua@fidmag.com
# *L. Morch-Johnsen
# *L. T. Westlye
# *FOR2107
# *FOR2107ControlGroup
# *FOR2107DiagnosticGroup
# *Kircher Tilo TJ
# *Lianne Schmaal
# *Schmaal
# *Lianne.schmaal@unimelb.edu.au
# *Lucija Abramovic
# *M. Fukunaga
# *Krug
# *Kruga@med.uni-marburg.de
# *M. Gill
# *Kircher
# *Kircher2@staff.uni-marburg.de
# *Marcel P. Zwiers
# *Donders Center for Cognitive Neuroimaging, Nijimegen
# *Frankfurt
# *SZFrankfurtIAP
# *FrankfurtControl
# *FrankfurtPatient
# *Michael Stäblein
# *Christian Knöchel
# *Frankfurt, Germany
# *HasNumberOfFemale (E)
# *25
# *Viola Oertel-Knöchel
# *UsedDiagnosisInstrument (E)
# *ConsensusConsultantDiagnosis
# *Mark E. Bastin
# *Brain Research Imaging Centre, University of Edinburgh,
# *Centre for Clinical Brain Sciences, University of Edinburgh
# *Department of Neuroimaging Sciences, University of Edinburgh,
# *Martine Hoogman
# *Hoogman
# *Martine.hoogman@radboudumc.nl
# *Department of Human Genetics, Radboud University
# *Masaki Fukunaga
# *Fukunaga
# *Fuku@nips.ac.jp
# *Division of Cerebral Integration
# *38NishigonakaMyodaijiAichi4448585
# *Fukunaga Masaki
# *National Institute for Physiological Sciences
# *Michael Gill
# *Michelle Luciano
# *Luciano
# *Michelle.luciano@ed.ac.uk
# *Galway
# *GalwayControlGroup
# *GalwayDiagnosticGroup
# *N. Banaj
# *N. T. Doan
# *Nailin Yao
# *Centre for addiction and mental health
# *GAP
# *GAPControlGroup
# *GAPDiagnosticGroup
# *Paola Dazzan
# *Simone Ciufolini
# *Neda Jahanshad
# *Jahanshad
# *Neda.jahanshad@usc.edu
# *Imaging Genetics Center, Mark and Mary Stevens Neuroimaging and Informatics Institute, Keck School of Medicine of USC
# *Paola.dazzan@kcl.ac.uk
# *Simone.ciufolini@kcl.ac.uk
# *Nerisa Banaj
# *GIPSI
# *GIPSIControlGroup
# *GIPSIDiagnosticGroup
# *Carlos López Jaramillo
# *Nhat Trung Doan
# *Doan
# *N.t.doan@medisin.uio.no
# *Nicholas G. Martin
# *QIMR Berghofer Medical Research Institute, Brisbane
# *Carloslopezjaramillo@gmail.com
# *Nicola J. Armstrong
# *Centre for Healthy Brain Ageing, Sydney
# *Mathematics and Statistics, Murdoch University
# *HMS
# *HMS-IAP
# *HMSControlGroup
# *HMSDiagnosticGroup
# *Odile van den Heuvel
# *Ole A. Andreassen
# *HUBIN
# *HUBINControlGroup
# *HUBINDiagnosticGroup
# *I. Agartz
# *Jonsson Erik G
# *Oliver Gruber
# *Gruber
# *Oliver.gruber@med.uni-heidelberg.de
# *Center for Translational Research in Systems Neuroscience and Psychiatry,Göttingen
# *P. De Rossi
# *P. M. Thompson
# *P. Suarez-Pinilla
# *Huilong1
# *Huilong1ControlGroup
# *Huilong1DiagnosticGroup
# *Peter Kochunov
# *Patricia J. Conrod
# *Department of Psychiatry, Montreal
# *Department of Psychological Medicine and Psychiatry, King's College
# *Pkochunov@gmail.com
# *Penny Gowland
# *Gowland
# *Penny.gowland@nottingham.ac.uk
# *Sir Peter Mansfield Imaging Centre School of Physics and Astronomy, Nottingham
# *Huilong2
# *Huilong2ControlGroup
# *Huilong2DiagnosticGroup
# *Pieter J. Hoekstra
# *Department of Psychiatry, Groningen
# *Indiana
# *Premika S.W. Boedhoe
# *Department of Psychiatry, VU University Medical Center
# *Department of Anatomy & Neurosciences, VU University Medical Center,
# *Neuroscience Campus Amsterdam
# *JHU
# *KASP
# *KASPControlGroup
# *KASPDiagnosticGroup
# *L. Flyckt
# *Prince Wang
# *Lena.flyckt@sll.se
# *R. C. Gur
# *KaSP
# *KaSPControlGroup
# *KaSPDiagnosticGroup
# *H. Fatouros-Bergman
# *R. Roiz-Santiañez
# *R. S. Kahn
# *Rene S. Kahn
# *Helena.fatouros-bergman@ki.se
# *Rosa Ayesa-Arriola
# *Ayesa-Arriola
# *Rayesa@humv.es
# *Department of Psychiatry, University Hospital Marqués de Valdecilla, Santander
# *IBERSAM, Centro Investigación Biomédica en Red Salud Mental, Santander
# *MADRID
# *Ryota Hashimoto
# *Hashimoto
# *Hashimor@psy.med.osaka-u.ac.jp
# *United Graduate School of Child Development
# *Department of Psychiatry, Osaka
# *MCIC
# *MCICControlGroup
# *MCICDiagnosticGroup
# *Stephan Erlich
# *Ehrlich Stefan
# *Osaka University
# *S. M. C. de Zwarte
# *Stefan.ehrlich@uniklinikum-dresden.de
# *Samantha Brooks
# *MPRC1
# *MPRC1ControlGroup
# *MPRC1DiagnosticGroup
# *Elliot Hong
# *Samuel R. Mathias
# *Department of Psychiatry, New Haven
# *Sara M
# *Lab of Neuropsychiatry
# *MPRC2
# *MPRC2ControlGroup
# *MPRC2DiagnosticGroup
# *Sarah Jurk
# *Department of Psychiatry and Neuroimaging Center, Dresden
# *Saskia Hagenaars
# *NU
# *NUControlGroup
# *NUDiagnosticGroup
# *Lei Wang
# *Silvia Brem
# *University Clinic for and Adolescent Psychiatry UCCAP, Zurich
# *Neuroscience Center Zurich
# *Leiwang1@northwestern.edu
# *Simon E Fisher
# *Language & Genetics Department, Max Planck
# *OLIN
# *OLINControlGroup
# *OLINDiagnosticGroup
# *David Glahn
# *Sonja M.C. de Zwarte
# *Stefan Ehrlich
# *Ehrlich
# *Stefan.ehrlich@tu-dresden.de
# *Department of Child and Adolescent Psychiatry, TU Dresden
# *Department of Psychiatry, Mass General
# *Martinos Center for Biomedical Imaging, Charlestown
# *Glahn
# *David.glahn@yale.edu
# *OsakaMR1
# *OsakaMR1ControlGroup
# *OsakaMR1DiagnosticGroup
# *R. Hashimoto
# *Sylvane Desrivières
# *Centre for Neuroimaging, Cognition & Genomics (NICOG), National University of Ireland Galway
# *T. Nickson
# *T. P. Gurholt
# *OsakaMR2
# *OsakaMR2ControlGroup
# *OsakaMR2DiagnosticGroup
# *Ted
# *Ted H
# *Tejal Patted
# *Oxford
# *Godlewska Beata
# *HasMembers (E)
# *Member1
# *PAFIP1.5T
# *PAFIP1.5TControlGroup
# *PAFIP1.5TDiagnosticGroup
# *Diana Tordesillas-Gutierrez
# *B. Crespo-Facorro
# *Thomas Espeseth
# *Espeseth
# *Thomas.espeseth@psykologi.uio.no
# *Tobias Banaschewski
# *Department of Child and Adolescent Psychiatry and Psychotherapy, Heidelberg University
# *Diana.tordesillas@humv.es
# *Tobias U. Hauser
# *University Clinic for Child and Adolescent Psychiatry, Zurich
# *Wellcome Trust Centre for Neuroimaging, London
# *UCL Max Planck Centre for Computational Psychiatry and Ageing
# *PAFIP3T
# *RomeSL
# *RomeSLControlGroup
# *RomeSLDiagnosticGroup
# *G. Spalletta
# *Tulio Guadalupe
# *International Max Planck Research School for Language Sciences, Nijmegen
# *G.spalletta@hsantalucia.it
# *Udo Dannlowsk
# *Department of Psychiatry, University of Münster
# *Department of Psychiatry, University of Marburg
# *RSCZ
# *RSCZControlGroup
# *RSCZDiagnosticGroup
# *Irina Lebedeva
# *Uli Bromberg
# *University Medical Centre Hamburg-Eppendorf, Hamburg
# *V. Ciullo
# *Irina.lebedeva@ncpz.ru
# *Lebedeva-i@yandex.ru
# *Varun Ratnakar
# *SaoPaulo
# *SaoPauloControlGroup
# *SaoPauloDiagnosticGroup
# *Vatche G. Baboyan
# *Victoria Knight
# *SCORE
# *SCOREControlGroup
# *SCOREDiagnosticGroup
# *Stefan Borgwardt
# *Vincent Frouin
# *Neurospin, Commissariat à l’Energie Atomique, CEA-Saclay Center
# *Stefan.borgwardt@upkbs.ch
# *Volker Arolt
# *SNUH
# *SNUHControlGroup
# *SNUHDiagnosticGroup
# *Jun Soo Kwon
# *W. Cahn
# *Yolanda Gil
# *Yoshinari Abe
# *Department of Psychiatry, Graduate School of Medical Science, Kyoto
# *Kwonjs@snu.ac.kr
# *TOP
# *TOPControlGroup
# *TOPDiagnosticGroup
# *Andreassen Ole A
# *Yuqi Chen
# *Department of Psychiatry, Kunming
# *SZPositiveSymptoms
# *D. P. Hibar
# *N. E. M. Van Haren
# *O. A. Andreassen
# *A. O. Berg
# *A. Farden
# *E. G. Jonsson
# *A. Preda
# *R. E. Gur
# *D. H. Wolf
# *T. D. Satterthwaite
# *I. E. Sommer
# *S. Koops
# *A. Richter
# *B. Kramer
# *C. McDonald
# *D. M. Cannon
# *A. Corvin
# *A. Di Giorgio
# *A. Bertolino
# *UMCU
# *UMCUS
# *UNIBA
# *UPENN
# *ENIGMA
# *O.a.andreassen@medisin.uio.no
# *UCIZSZ
# *DepressionWG
# *WorkingGroup (E)
# *HasWGChair (E)
# *UMCUControlGroup
# *UMCUDiagnosticGroup
# *Roel Ophoff
# *Hulshoff Pol Hilleke E
# *Sommer Iris E
# *LateralityWorkingGroup
# *SubcorticalLatProject
# *OCD WG
# *Van den Heuvel Odile A
# *Boedhoe Premika
# *Stein Dan J
# *Premika Boedhoe
# *N.e.m.vanharen@umcutrecht.nl
# *SZWorkingGroup
# *UNIMAAS
# *UNICAMP
# *SZCorticol
# *SZNegativeSymptoms
# *HasWGBriefDescription (E)
# *UMCUSControlGroup
# *UMCUSDiagnosticGroup
# *Access Controlled Page
# *PIGroup
# *S.koops@umcutrecth.nl
# *JuniorLeadGroup
# *UNIBAControlGroup
# *UNIBADiagnosticGroup
# *Digiorgioannabella@gmail.com
# *Alessandro.bertolino@uniba.it
# *UPENNControlGroup
# *UPENNDiagnosticGroup
# *Sattertt@mail.med.upenn.edu
# *Agnes McMahon
# *Aiden Corvin
# *Alejandro Arias-Vasquez
# *Department of Psychiatry, Radboud University
# *GeertGrootepleinZuid106525GA
# *Buitelaar Jan K
# *Donders Institute for Brain, Cognition and Behaviour
# *Amy Jang
# *Andre F. Marquand
# *Department of Neuroimaging, London
# *Andrea Gonzalez Suarez
# *Service of Neurology, University of Cantabria, Santander
# *Andreas Heinz
# *Heinz
# *Andreas.heinz@charite.de
# *Department of Psychiatry and Psychotherapy, Berlin
# *Anna Cattrell
# *Medical Research Council - Social, Genetic and Developmental Psychiatry Centre,
# *Annette Conzelmann
# *Department of Psychology, Würzbur
# *Department of Child and Adolescent Psychiatry and Psychotherapy, Tübingen
# *Anushree Bose
# *Department of Psychiatry, Bangalore
# *Arun L. W. Bokde
# *Discipline of Psychiatry, School of Medicine and Trinity College Institute of Neurosciences
# *Benedicto Crespo-Facorro
# *Crespo-Facorro
# *Benedicto.crespo@unican.es
# *Benjamin S. Aribisala
# *Department of Computer Science, Lagos
# *Brain Research Imaging Centre, Edinburgh
# *Bernard Mazoyer
# *CRNS University of Bordeaux
# *Bernd Ittermann
# *Physikalisch-Technische Bundesanstalt, Berlin, Braunschweig
# *Bernd Kraemer
# *Bernhard T. Baune
# *Discipline of Psychiatry, University of Adelaide
# *Chad A
# *Degree (E)
# *Chaim Huyser
# *Academic Center for Child and Adolescent Psychiatry, Amsterdam
# *Department of child and adolescent psychiatry, Amsterdam
# *Christian Büchel
# *Christine Lochner
# *Christopher D. Whelan
# *Imaging Genetics Centre, Institute for Neuroimaging, & Infomatics, USC
# *Molecular and Cellular Therapeutics, Ireland
# *Clyde Francks
# *Francks
# *Clyde.francks@mpi.nl
# *Daniel Garijo
# *Dara M. Cannon
# *Dara W
# *Derrek P. Hibar
# *Dominik Grotegerd
# *Grotegerd
# *Dominik.grotegerd@wwu.de
# *Eric Artiges
# *Erik G. Jönsson
# *Forskningsveien3A373
# *855NWolfeStSuite3003rdFloorMaryland21205
# *97BddePortRoyal75014
# *ReinierPostlaan126525GA
# *Pevensey121211E1OokayamaMeguroku1528500
# *Rapenburg702311EZ
# *16DeCrespignyParkSE58AF
# *Kraepelinstr21080804
# *3560BathurstStreetOntarioM6A2E1
# *11YamadaokaSuitaOsakaPrefecture5650871
# *GeorgeSqEH164SB
# *Edinburgh
# *DeBoelelaan10851081HV
# *MPIP
# *T1-weighted
# *MPIP Control Group
# *MPIP MDD Group
# *HasDocuments (E)
# *SignedMOU
# *Illumina 100K, Illumina 300K, Illumina 550K, Illumina 610K, Illumina 660K
# *Samann Philipp G
# *MDD DTI 2018
# *MDD Insomnia
# *MDD Machine Learning
# *FruitStreetMassachusetts2115
# *Massachusetts
# *PB85Vinderen319
# *GowerStWC1E6BT
# *KarolinskaUniversityHospitalSolnaHouseR5:00SE17176
# *200HawkinsDriveW278GHIowa52242
# *3210MerryfieldRowCalifornia92121
# *California
# *4150ClementStCalifornia94121
# *VanderBoechorststraat11081BT
# *1SouthProspectStreetVermont5401
# *CNV WG
# *Sonderby Ida E
# *AnzioRoadWesternCaliforniape7925
# *HasMinAge (E)
# *CoreWG
# *HIV WG
# *HIV DTI
# *HIV Subcortical Volumes
# *Jahanshad Neda
# *Fouche JP
# *Cohen Ron
# *Nir Talia
# *Toranomon15MoriBuilding2F2810ToranomonMinatoku1050001
# *AdultCrossWG
# *Sleep WG
# *Tahmasian Masoud
# *100StGeorgeStreetOntarioM5S3G3
# *1UniversityofNewMexicoNewMexico87131
# *DeBoelelaan11051081HV
# *Hanzeplein19713GZ
# *Groningen
# *9500GilmanDriveCalifornia92093
# *EuroaCentrePrinceofWalesHospitalBarkerStreetNewSouthWales2031
# *Australia
# *Sydney
# *WilhelmKleinStrasse274012
# *D322Yamadaoka5650871
# *Osaka
# *DeCrespignyParkSE58AF
# *EpigeneticsWG
# *Desrivieres Sylvane
# *Schumann Gunter
# *7GeorgeSquareEH89JZ
# *TbfMRI WG
# *Walter Henrik
# *Veer Ilya
# *GeertGrootteplein10Gelderland6525GA
# *3641WattWayHNB10090089
# *35PoplarRoadVictoria3052
# *BrainResearchImagingCentreWesternGeneralHospitalCreweRoadEH42XU
# *GWAS WG
# *Stein Jason L
# *Medland Sarah E
# *Hibar Derrek P
# *J568159
# *BrainInjuryWG
# *Tate David
# *Wilde Lisa
# *Dennis Emily
# *Vossstr4D69115
# *South Texas Diabetes and Obesity Institute
# *Curran Joanne E
# *Blangero John
# *Almeida Marcio AA
# *2700EJacksonStTexas78578
# *University of Texas Rio Grande School of Medicine
# *Department of Psychiatry and Human Behavior-UCI
# *Nakahara Soichiro
# *Macciardi Fabio
# *5251CaliforniaAvenueSuite24092617
# *University of California, Irvine
# *Department of Psychiatry-LUMC
# *Van der Wee Nic JA
# *Albinusdreef22333ZA
# *Leiden University Medical Center
# *Department of Medicine and Psychiatry
# *Crespo Facorro Benedicto
# *RoizSantianez Roberto
# *University Hospital Marques de Valdecilla, School of Medicine
# *2400tuckerNENewMexico87131
# *Department of Psychiatry-MGH
# *Holmes Avram J
# *Smoller Jordan W
# *55FruitStMassachusetts2114
# *Massachusetts General Hospital
# *4placeGeneralLeclercORSAY91401
# *Department of Biological and Medical Psychology
# *HaukelandHospital
# *University of Bergen
# *855NWolfeStMaryland21205
# *Department of Psychiatry-UCSD
# *Jernigan Terry L
# *University of California, San Diego
# *LuitenantLippenslaan552140
# *300HerstonRoadQueensland4006
# *LloydBuildingD2
# *Dublin
# *355W16thStSte4100Indiana46202
# *415MainStreet2142
# *Center for Neurobehavioral Genetics
# *Olde Loohuis Loes M
# *695CharlesEYoungDriveSouthCalifornia90095
# *University of California, Los Angeles
# *Center for Genomic Medicine
# *Lee Phil H
# *185CambridgeStMassachusetts2114
# *Tatzberg47511307
# *StLuciaQueensland4072
# *90SouthStWesternAustralia6150
# *Heidelberglaan1003508GA
# *KelvinGroveQueensland4059
# *NormanbyHouseStGeorgesHospital283CothamRdVictoria3101
# *Centre for Cognitive Ageing and Cognitive Epidemiology
# *Luciano Michelle
# *Deary Ian J
# *Wardlaw Joanna M
# *University of Edinburgh
# *Brain Center Rudolf Magnus
# *Hillegers Manon HJ
# *Van Haren Neeltje EM
# *Kahn Rene S
# *Koops Sanne
# *De Zwarte Sonja MC
# *Buimer Elizabeth EL
# *Veldink Jan H
# *Luykx Jurjen J
# *Brouwer Rachel M
# *University Medical Centre Utrecht
# *90095
# *Nachtigallenweg8653127
# *Hashimoto Ryota
# *EPIGEN
# *Sisodiya Sanjay M
# *Department of Neurology-AC
# *Posthuma Danielle
# *Alzheimer Center
# *Assareh Amelia A
# *Assareh
# *Amelia.assareh@health.nsw.gov.au
# *4676AdmiraltyWayCalifornia90292
# *3775RueUniversity316H3A2B4
# *Cardiff University Brain Research Imaging Centre
# *Foley Sonya F
# *Lancaster Thomas M
# *MaindyRoadCF244HQ
# *Cardiff University
# *Department of Medical and Molecular Genetics
# *Saykin Andrew J
# *Indiana University School of Medicine
# *Department of Complex Trait Genetics
# *Jansen Iris E
# *Polderman Tinca JC
# *Vrije Universiteit Amsterdam
# *845SherbrookeStWQuebecH3A0G4
# *Center for Economics and Neuroscience
# *Hausler Alexander N
# *University of Bonn
# *CIBERSAM (Centro Investigacion Biomedica en Red Salud Mental)
# *TordesillasGutierrez Diana
# *Ayesa Arriola Rosa
# *Almeida
# *Marcio.Almeida@utrgv.edu
# *AvdaValdecillasn39008
# *Chen Qiang
# *Chen
# *Danny.chen@libd.org
# *Departments of Psychiatry and Biological and Biomedical Engineering
# *Chakravarty Mallasr
# *McGill University
# *34BotanyStreetNewSouthWales2031
# *ChildCrossWG
# *2312S6thStMIndiananesota55454
# *MIndiananesota
# *AvenueFranklinRoosevelt501050
# *BurgemeesterOudlaan503062PA
# *Department of Psychology-YU
# *2HillhouseAveConnecticut6520
# *Yale University
# *Brain and Mind Centre
# *The University of Sydney
# *CEAParisSaclay91191
# *Boedhoe Premika SW
# *Boedhoe
# *P.boedhoe@vumc.nl
# *Center for Medical Genetics and Molecular Medicine
# *Le Hellard Stephanie
# *HaukelandUniversityHospital5021
# *Department of Psychiatry-UV
# *Uhlmann Anne
# *University of Vermont
# *Core-Unit Brainimaging
# *Jansen Andreas
# *White Tonya
# *White
# *T.white@erasmusmc.nl
# *Zwiers Marcel P
# *Zwiers
# *M.zwiers@donders.ru.nl
# *94MalletStreetNewSouthWales2050
# *Department of Psychology-GSU
# *Walton Esther
# *140DecaturStreetGeorgia303033083
# *Georgia State University
# *Baune Bernhard T
# *Baune
# *Bernhard.baune@me.com
# *Athinoula A. Martinos Center for Biomedical Imaging
# *Ge Tian
# *14913thStreetMassachusetts2129
# *Department of Psychiatry-ZNA
# *ZNA Hospitals
# *Department of Integrative Medical Biology
# *Nyberg Lars
# *Andersson Micael
# *Linnusvg990187
# *Umea Center for Functional Brain Imaging
# *Department of Clinical Science
# *Djurovic Srdjan
# *Bustillo Juan R
# *Bustillo
# *Jbustillo@salud.unm.edu
# *BETULA
# *Cardiff
# *Caseras Xavier
# *4placeGeneralLeclerc91401
# *Bristol Medical School
# *University of Bristol
# *Department of Clinical Neuropsychology
# *Oosterlaan Jaap
# *Centre for Healthy Brain Ageing
# *Thalamuthu Anbupalam
# *Brodaty Henry
# *Mather Karen A
# *Sachdev Perminder S
# *Reppermund Simone
# *Wen Wei
# *EuroaCentrePrinceofWalesHospitalviaGate6AvocaStreetNewSouthWales2031
# *University of New South Wales
# *De Geus Eco JC
# *J.c.n.de.geus@vu.nl
# *BIG-Psych
# *Franke Barbara
# *Brandt Christine L
# *Brandt
# *C.l.brandt@medisin.uio.no
# *Departments of Psychology and Psychiatry
# *Paus Tomas
# *University of Toronto
# *ADNI
# *3801BoulevardRobertBourassaQuebecH3A2B4
# *Cahn Wiepke
# *Cahn
# *Wcahn@umcutrecht.nl
# *ColodroConde Lucia
# *Colodro-Conde
# *Lucia.colodroconde@qimrberghofer.edu.au
# *Department of Pediatrics
# *DeBoelelaan11171007MB
# *VU Medical Center
# *Department of Genomics
# *Forstner Andreas J
# *SigmundFreudStrasse2553127
# *Life & Brain Center
# *Bralten Janita
# *Bralten
# *Janita.Bralten@radboudumc.nl
# *Department of Child and Adolescent Psychiatry-EUR
# *DrMolewaterPlein603000CB
# *Erasmus University Rotterdam
# *445ParkAvenueNewYork10022
# *Amsterdam Neuroscience
# *Cheung Joshua W
# *Cheung
# *Joshua.Cheung@loni.usc.edu
# *22Yamadaoka5650871
# *9712CP
# *3720W69thStreetSouthDakota57108
# *Department of Psychiatry and Psychotherapy-CUB
# *Heinz Andreas
# *Charitplatz110117
# *Charite Universitatsmedizin Berlin
# *Department of Psychiatry-UMCU
# *Heidelberglaan1003874CN
# *Department of Psychiatry and Weill Institute for Neurosciences
# *Mathalon Daniel H
# *University of California, San Francisco
# *Department of Cognitive and Clinical Neuropsychology
# *Heslenfeld Dirk J
# *Department of Psychiatry-VUA
# *Schmaal Lianne
# *Milaneschi Yuri
# *Penninx Brenda WJH
# *1081HL
# *Department of Neuroscience-UG
# *Van Tol MarieJose
# *ADeusinglaan29713AW
# *University of Groningen
# *1WestUniversityBlvdTexas78520
# *Centre for Advanced Imaging
# *McMahon Katie L
# *Wright Margaret J
# *McMahon Mary Agnes B
# *University of Queensland
# *Calhoun Vince
# *Calhoun
# *BRIDGE
# *BIG
# *300HerstonRdQueensland4006
# *Department of General Psychiatry
# *Heidelberg University
# *10BuangkokView539747
# *123StStephensGreenLeIndianaster
# *Center for Cognitive Neuroscience
# *Zhou Juan
# *8collegeroad0615169857
# *Neuroscience and Behavioral Disorders Program
# *Agartz Ingrid
# *Center for Human Development
# *Berger Christian
# *Christian.Buerger@ukmuenster.de
# *Department of Psychiatry and Mental Health-UCT
# *GSHJ2BlockAnzioRoad7925
# *University of Cape Town
# *Armstrong Nicola J
# *Armstrong
# *N.armstrong@murdoch.edu.au
# *3D T1 weighted sequence
# *22q WG
# *Bearden Carrie
# *Villalon Julio
# *5007
# *57NorthTerraceSouthAustralia5000
# *115MasonFarmRdRoom8109CNC275997250
# *Department of Psychiatry (UPK)
# *University of Basel
# *Avera Institute for Human Genetics
# *Davies Gareth E
# *Department of Human Genetics
# *Shumskaya Elena
# *Klein Marieke
# *Van Donkelaar Marjolein MJ
# *Hoogman Martine
# *Roth Mota Nina
# *Radboud University Medical Center
# *Bipolar Family Study (BFS)
# *McIntosh Andrew
# *Carver College of Medicine
# *AlbertSchweitzerCampus1BldgA948161
# *Department of Psychiatry-DIB
# *POBox91016500HB
# *Child Mind Institute
# *Department of Neurology-UMCU
# *Department of Neuroinformatics
# *Kanai Ryota
# *Araya, Inc.
# *1101YaleBlvdNENewMexico87106
# *Bernard Manon
# *Bernard
# *Manon-bernard@videotron.ca
# *Dementia Centre for Research Collaboration
# *AGSM302UNSWNewSouthWales2052
# *Dalvie Shareefa
# *Dalvie
# *Dlvsha006@myuct.ac.za
# *Department of Radiology and Imaging Sciences
# *Nho Kwangsik
# *Department of Epileptology
# *Weber Bernd
# *SigmundFreudStr2553127
# *University Hospital Bonn
# *Department of Biomedicine
# *Department of Genetics & UNC Neuroscience Center
# *Zsembik Leo
# *University of North Carolina at Chapel Hill
# *Department of Psychiatric Research
# *Diakonhjemmet Hospital
# *Department of Cognitive and Clinical Neuroscience
# *Flor Herta
# *SquareJ568159
# *Central Institute of Mental Health
# *CamperdownNewSouthWales2006
# *Division of Psychological & Social Medicine
# *Fetscherstrae741307
# *Technische Universitat Dresden
# *Department of Biological Psychology
# *Vant Ent Dennis
# *Boomsma Dorret I
# *Fedko Iryna O
# *Hottenga Jouke Jan
# *VanderBoechoststraat11081BT
# *CF103AT
# *Department of Psychiatry-OUGSM
# *Yamamori Hidenaga
# *Osaka University Graduate School of Medicine
# *Department of Psychiatry-MU
# *Karama Sherif
# *6875LasalleBoulevardQuebecH4H1R3
# *Division of Human Genetics
# *Engelbrecht Hannah Ruth
# *Institute of Infectious Disease and Molecular Medicine
# *Department of Genetics
# *Weinberger Daniel R
# *Johns Hopkins University
# *Dr. Einar Martens Research Group for Biological Psychiatry
# *Steen Vidar M
# *Giddaluru Sudheer
# *Haukeland University Hospital
# *198DengakugakuboKutsukakeAichi4701192
# *Departments of Psychiatry
# *AddictionWG
# *Garavan Hugh
# *Mackey Scott
# *Conrod Patricia
# *EasyStreetNewSouthWales2031
# *Department of Genome Informatics
# *Kikuchi Masataka
# *AnxietyWG
# *BasHoogendam Janna Marie
# *Groenewold Nynke A
# *3330HospitalDriveNWAlbertaT2N4N1
# *Alberta
# *California90007
# *Curran
# *Joanne.curran@utrgv.edu
# *Department of Psychiatry-UNM
# *University of New Mexico
# *AtaxiaWG
# *Harding Ian
# *Department of Clinical Genetics
# *101TheCithDriveSCalifornia92865
# *Biegenstrae1035037
# *Davies
# *Gareth.Davies@avera.org
# *Discipline of Psychiatry
# *University of Adelaide
# *Department of Electrical and Computer Engineering
# *Caseras
# *Caserasx@cardiff.ac.uk
# *Djurovic
# *Srdjan.djurovic@medisin.uio.no
# *Center for Neuroimaging and Indiana Alzheimer Disease Center
# *S.m.c.dezwarte@umcutrecht.nl
# *CancerChemoWG
# *Shiroishi Mark
# *Department of Child and Adolescent Psychiatry-Psychology-EMC
# *Wytemaweg83000CB
# *Erasmus Medical Center
# *Engelbrecht
# *NGLHAN001@myuct.ac.za
# *Division of Mental Health and Addiction
# *Espeseth Thomas
# *Oslo University Hospital
# *Dietsche Bruno
# *Dietsche
# *Dietsche@med.uni-marburg.de
# *Department of Molecular and Cellular Therapeutics
# *Alhusaini Saud
# *123StStephen'sGreenLeIndianaster
# *Royal College of Surgeons in Ireland
# *Domstrae1117489
# *Department of Psychiatry-UMu
# *Zaremba Dario
# *Grotegerd Dominik
# *Dohm Katharina
# *Opel Nils
# *Redlich Ronny
# *Dannlowski Udo
# *Repple Jonathan
# *AlbertSchweitzerCampus148149
# *University of Munster
# *Grasby Katrina L
# *Grasby
# *Katrina.grasby@qimrberghofer.edu.au
# *Fan Chun Chieh
# *Fan
# *C9fan@ucsd.edu
# *340W10thSt6200Indiana46202
# *Department of Psychiatry-UHMV
# *401ParkDriveMassachusetts2215
# *CalleCardenalHerreraOria39011
# *Andersson
# *Micael.andersson@umu.se
# *ENIGMA3 Cortical GWAS
# *Thompson Paul M
# *Painter Jodie N
# *Lind Penelope A
# *T1-weighted MRI
# *IMpACT
# *NeuroIMAGE
# *CHOP
# *BONN
# *GIG
# *GOBS
# *GROUP
# *GSP
# *HUNT
# *ID1000
# *IGC
# *IMAGEN
# *IMH
# *LBC1936
# *LIBD
# *MAS
# *OATS
# *Meth-CT
# *MUNSTER
# *NCNG
# *NESDA
# *NTR-Adults
# *Brainscale
# *PAFIP
# *PING
# *QTIM
# *SHIP
# *SHIP-TREND
# *SYS
# *TOP3T
# *UMCU & BrainSCALE
# *Enigma.genetics@gmail.com
# *Schofield Peter R
# *Hansell Narelle K
# *CouvyDuchesne Baptiste
# *Martin Nicholas G
# *Martinot Jean Luc
# *Glahn David C
# *Mathias Samuel R
# *Kramer Bernd
# *Kasperaviciute Dalia
# *Putz Benno
# *Mirza Schreiber Nazanin
# *Wolf Christiane
# *Wang Yunpeng
# *Dale Anders M
# *Ikeda Masashi
# *Knapp Michael
# *WittStephanie
# *Witt Stephanie H
# *Sim Kang
# *Ho Beng Choon
# *Francks Clyde
# *Fisher Simon E
# *Kwok John BJ
# *Gruber Oliver
# *Fernandez Guillen
# *Whelan Robert
# *Shin Jean
# *Quinlan Erin B
# *Haberg Asta K
# *Preda Adrian
# *Lim Kelvin O
# *Turner Jessica A
# *Van Eijk Liza
# *Strike Lachlan T
# *De Zubicaray Greig I
# *Gollub Randy L
# *Lewis Lindsay B
# *Bastin Mark E
# *Riedel Brandalyn C
# *Harrison Marc B
# *Zhu Alyssa H
# *Salminen Lauren
# *Saremi Arvin
# *Van der Meer Dennis
# *Marquand Andre F
# *Gutman Boris A
# *Rashid Faisal M
# *Thomopoulos Sophia I
# *Ragothaman Anjanibhargavi
# *Ching Christopher RK
# *Van Rooij Daan
# *Doan Nhat Trung
# *Kaufmann Tobias
# *Westlye Lars T
# *Gurholt Tiril P
# *Papadopoulos Orfanos Dimitri
# *Goldman Aaron L
# *Pizzagalli Fabrizio
# *Shatokhina Natalia
# *Heindel Walter
# *Pike Bruce
# *Veltman Dick J
# *Gowland Penny A
# *Ames David
# *Mattay Venkata S
# *O Leary Daniel S
# *Mueller Bryon A
# *Krug Axel
# *Brouwer
# *Brouwer Rachel
# *R.m.brouwer-4@umcutrecht.nl
# *6875LaSalleBoulevardH4H1R3
# *Andreassen
# *Ole.andreassen@medisin.uio.no
# *Deusinglaan29700RB
# *Buimer
# *Buimer Elizabeth
# *Eelbuimer@gmail.com
# *Bastin
# *Mark.Bastin@ed.ac.uk
# *40TempleStreetSuit6EConnecticut6511
# *Connecticut
# *Department of Neuroscience and Department of Psychiatry
# *Couvy-Duchesne
# *B.couvyduchesne@uq.edu.au
# *Ching
# *Chris.Ching@loni.usc.edu
# *5005
# *Freesurfer5.1
# *Department of Radiology-EUR
# *DrMolewaterplein603000CB
# *Comeniuslaan4Gelderland6525HP
# *German Center of Neurodegenerative Disease (DZNE)
# *200RetreatAveConnecticut6106
# *Department of Psychiatry and Psychotherapy-UG
# *Medical Faculty Mannheim
# *Hartman Catharina A
# *Hartman
# *C.hartman@accare.nl
# *Centre for Psychiatric Research
# *Department of Clinical Neuroscience
# *G.fernandez@donders.ru.nl
# *Hopital Erasme
# *16DeCrespignyParkDenmarkHillSE58AF
# *695CharlesYoungDriveSouth90095
# *Genetic Epidemiology
# *QIMR Berghofer Medical Research Institute
# *Grabe
# *Grabeh@uni-greifswald.de
# *Department of Psychology-UE
# *Ikeda
# *Ikeda-ma@fujita-hu.ac.jp
# *Graduate Interdepartmental Program in Neuroscience
# *UCLA School of Medicine
# *Dale
# *Andersmdale@gmail.com
# *Forstner
# *Forstner@uni-bonn.de
# *Fujita Health University School of Medicine
# *Fujita Health University
# *Hansell
# *N.hansell@uq.edu.au
# *Department of Translational Neuroscience
# *Universiteitsweg1003508GA
# *Duke-National University of Singapore Medical School
# *Duke-National University of Singapore
# *EEG WG
# *Smit Dirk
# *Franke
# *Barbara.franke@radboudumc.nl
# *Sylvane.desrivieres@kcl.ac.uk
# *Anh@uni-bonn.de
# *Fedko
# *I.o.fedko@vu.nl
# *IrritabilityWG
# *Althoff Robert
# *Imaging Genetics Center
# *Mark and Mary Stevens Neuroimaging and Informatics Institute
# *Douglas Mental Health University Institute
# *686BayStreet109705OntarioM5G0A4
# *Freesurfer5.3
# *Department of Neuroscience-JHU
# *Heindel
# *Heindel@uni-muenster.de
# *Deptartment of Genetic Epidemiology in Psychiatry
# *1GustaveLLevyPlNewYork10029
# *Department of Psychiatry and Psychotherapy-PUM
# *Jansennnnn Andreas
# *Icahn School of Medicine at Mount Sinai
# *Department of Psychiatry-UG
# *Hoekstra Pieter J
# *Foley
# *Foleys2@cardiff.ac.uk
# *Groenewold
# *Nynke.groenewold@uct.ac.za
# *Department of Radiation Sciences
# *Norrlandsuniversitetssjukhus90187
# *Umea University
# *INSERM
# *LIBD Sample Data
# *File:LIBD.xlsx
# *DiskTestLIBD
# *Gravendijkwal2303015CE
# *Hoekstra
# *P.hoekstra@accare.nl
# *Giddaluru
# *Sudheer.giddaluru@med.uib.no
# *Center for Multimodal Imaging and Genetics
# *9500GilmanDrCalifornia92037
# *Grabengasse169117
# *Jernigan
# *Tjernigan@ucsd.edu
# *Harvard Medical School
# *Erik.jonsson@ki.se
# *Interdisciplinary Center of Psychopathology and Emotion Regulation (ICPE) & Research School of Behavioral and Cognitive Neuroscience
# *University Medical Center Groningen
# *Institute of Psychiatry, Psychology and Neuroscience
# *King's College London
# *CarmodyRoadQueensland4072
# *LateralityWG
# *Guadalupe Tulio
# *Department of Psychiatry-FHUSM
# *Hgskoleringen17491
# *Lancaster
# *LancasterTM@cardiff.ac.uk
# *Kraepelinstr280804
# *Lieber Institute for Brain Development
# *Greig.dezubicaray@qut.edu.au
# *Department of Neuroscience-NUST
# *MTFSOlavKyrresgt97030
# *Norwegian University of Science and Technology
# *INSERM Unit 1000 - neuroimaging & psychiatry
# *Janssen Research and Development, LLC
# *Gurholt
# *Gurholt Tiril
# *T.p.gurholt@medisin.uio.no
# *Gollub
# *Rgollub@partners.org
# *Le Hellard
# *Stephanie.hellard@uib.no
# *Department of Clinical Radiology
# *Meibergdreef91100DD
# *Heidelberglaan1003584CX
# *Department of Developmental Disability Neuropsychiatry
# *Broad Institute
# *Department of Radiology-JHU
# *Molecular Research Center for Children's Mental Development
# *Asta.haberg@ntnu.no
# *Department of Psychiatry-HMS
# *Centre for Clinical Brain Sciences and Edinburgh Imaging
# *Melle Ingrid
# *Melle
# *Ingrid.melle@medisin.uio.no
# *Department of Psychiatry-YUSM
# *Yale University School of Medicine
# *Hulshoff Pol
# *H.e.hulshoff@umcutrecht.nl
# *Kahn
# *Rene.kahn@mssm.edu
# *Department of Radiology & Clinical Neurosciences
# *University of Calgary
# *Macciardi
# *Fmacciar@uci.edu
# *Language and Genetics Department
# *Wundtlaan16525XD
# *Max Planck Institute for Psycholinguistics
# *Keck School of Medicine of USC
# *University of Southern California
# *EatingDisordersWG
# *Harrison
# *Marcharr@stanford.edu
# *Centre for Developing Brain
# *Lind
# *Penelope.lind@qimrberghofer.edu.au
# *NeuroSpin, CEA
# *Universite Paris Saclay
# *Kaufmann
# *Tobias.kaufmann@medisin.uio.no
# *AuthorRules:ENIGMA3 Cortical GWAS
# *Special:AuthorGeneration?project=ENIGMA3 Cortical GWAS
# *AuthorGeneration?project=ENIGMA3 Cortical GWAS
# *Campus Charite Mitte
# *Alhusaini
# *Saud.alhusaini@gmail.com
# *Martin
# *Nick.Martin@qimrberghofer.edu.au
# *Illumina 100K
# *Illumina 300K
# *Illumina 550K
# *Illumina 610K
# *Illumina 660K
# *T1-weighted SPGR sagittal 3D volume
# *FreeSurfer5.3
# *Hartford Hospital
# *Neurogenetics and Epigenetics
# *Department of Psychiatry-CCM
# *I work at USC
# *Neda.Jahanshad@ini.usc.edu
# *Neda.Jahanshad@usc.edu
# *Department of Radiology-UCSD
# *McMahon
# *Katie.mcmahon@cai.uq.edu.au
# *Karolinska Institutet
# *Holmes
# *Avram.holmes@yale.edu
# *K.G. Jebsen Centre for Psychosis Research and the Norwegian Centre for Mental Disorders Research (NORMENT)
# *Kirkeveien166450
# *University of Oslo
# *General Psychiatry
# *Institute of Mental Health
# *Martinot
# *Jean-luc.martinot@inserm.fr
# *Mirza-Schreiber
# *Nazanin@psych.mpg.de
# *MRC Integrative Epidemiology Unit
# *OakfieldHouseBS82BN
# *Opel
# *N opel01@uni-muenster.de
# *CheshamLaneSL90RJ
# *JosefSchneiderStrae297080
# *Lim
# *Kolim@umn.edu
# *MRC Centre for Neuropsychiatric Genetics and Genomics
# *Fisher
# *Simon.fisher@mpi.nl
# *HighStreetNewSouthWales1466
# *OldCollegeSouthBridgeEH89YL
# *FDT WG
# *Altmann Andre
# *Rohrer Jon
# *Department of Neuroscience Biomarkers
# *KarolinskaUniversityHospitalSolnaHouseR5:0017176
# *Mathias
# *Samuel.mathias@yale.edu
# *Nyberg
# *Lars.nyberg@umu.se
# *Penninx
# *B.penninx@vumc.nl
# *Ho
# *Beng-ho@uiowa.edu
# *Nho
# *Knho@iupui.edu
# *Heslenfeld
# *D.j.heslenfeld@vu.nl
# *Paus
# *Tpaus@research.baycrest.org
# *Institute for Medical Statistics, Informatics and Epidemiology
# *SigmundFreudStrasse25D53105
# *Ragothaman
# *Ragotham@ohsu.edu
# *AutismWG
# *Medland
# *Sarah.medland@qimrberghofer.edu.au
# *Painter
# *Jodie.painter@qimrberghofer.edu.au
# *McGill Centre for Integrative Neuroscience
# *Leiden University
# *Department of Psychiatry-UM
# *University of Minnesota
# *Dannlowski
# *Dannlow@uni-muenster.de
# *Deary
# *I.deary@ed.ac.uk
# *Pizzagalli
# *Fabrizio
# *Fabrizio.Pizzagalli@ini.usc.edu
# *Nakahara
# *Nakahars@uci.edu
# *QTIM Control Group
# *QTIM MDD Group
# *Illumina Human610-Quad BeadChip
# *Psychiatric Genetics
# *Preda
# *Apreda@uci.edu
# *Jansen
# *Ie.jansen@vumc.nl
# *INSERM U.1000 - Maison de Solenn
# *EvolutionWG
# *Ames
# *Dames@unimelb.edu.au
# *Psychiatric & Neurodevelopmental Genetics Unit
# *Kapittelweg296525EN
# *NewMexico
# *HighStNewSouthWales2052
# *Quinlan
# *Erin.quinlan@kcl.ac.uk
# *Lewis
# *Lindsayblewis@gmail.com
# *Institute of Living
# *NY-testdata-25July2018
# *HasAuthor
# *Naomi
# *HasFileType
# *CSV
# *HasFileUpload
# *File:Dogs.csv
# *HasFileUploadLink
# *Http://organicdatacuration.org/enigma new/images/f/f0/Dogs.csv
# *HasInstitution
# *HasSpreadsheetLink
# *Https://docs.google.com/spreadsheets/d/1UocUUKGOMJYJQMjACffIXDz8-Er3s2e4c0I0hU8MCOQ/edit?usp=sharing
# *TestPurposes
# *NewSouthWales2052
# *Shatokhina
# *Natalya.Shatokhina@loni.usc.edu
# *Natalia.shatokhina@gmail.com
# *RelativesWG
# *Hotchkiss Brain Institute
# *Centre for Youth Mental Health
# *University of Melbourne
# *Klein
# *Marieke.klein@radboudumc.nl
# *Sackler Centre for Consciousness Science
# *SussexBN19QH
# *School of Psychology-University of Sussex
# *National Ageing Research Institute
# *PoplarRdVictoria3052
# *LifespanWG
# *Dima Danai
# *Rasgon Alexander
# *Frangou Sophia
# *Mmcmahon@ini.usc.edu
# *Sisodiya
# *S.sisodiya@ucl.ac.uk
# *Olin Neuropsychiatric Research Center
# *Radbound University
# *HippoSubWG
# *Saemann Philipp
# *3801RobertBourassaQuebecH3A2B4
# *Pike
# *Bruce.pike@ucalgary.ca
# *Montreal Neurological Institute and Hospital
# *686BayStreetOntarioM5G1X8
# *Scz subcortical project
# *Scz DTI project
# *POBox5010Georgia30302
# *SpragueHall839HealthSciencesRoadCalifornia92697
# *School of Psychiatry-SMS
# *School of Medical Sciences
# *Chalfont Centre for Epilepsy
# *StorageDiseaseWG
# *Karkashadze George
# *Namazova Leyla
# *PlasticityWG
# *Hulshoff-Pol Hilleke
# *School of Psychology-TCD
# *Trinity College Dublin
# *Institute of Health and Biomedical Innovation
# *Queensland University of Technology (QUT)
# *Saemann@psych.mpg.de
# *Section for Experimental Psychopathology and Neuroimaging
# *Riedel
# *Brandalyn.Riedel@loni.usc.edu
# *Schlossplatz248149
# *Hillegers
# *M.hillegers@erasmusmc.nl
# *Mathematics and Statistics
# *Murdoch University
# *Marquand
# *A.marquand@donders.ru.nl
# *Wolf
# *Wolf C5@ukw.de
# *Redlich
# *R.redlich@uni-muenster.de
# *Hebelstrasse204031
# *Polderman
# *Tinca.polderman@vu.nl
# *Department of Psychiatry-SU
# *FrancievanZijlAvenue7500
# *Stellenbosch University
# *HasWGJuniorLead (E)
# *SenateHouseTyndallAveBS81TH
# *Oldenaller11081HL
# *Emma Children's Hospital Academic Medical Center
# *Mind Research Network
# *NC27599
# *School of Psychology-UQ
# *Smoller
# *Jsmoller@mgh.harvard.edu
# *Department of Cognitive Science
# *StrokeWG
# *Liew Sook-Lei
# *Witt
# *Stephanie.witt@zi-mannheim.de
# *Institute of Medical Genetics and Pathology
# *Schnbeinstrasse404031
# *University Hospital Basel
# *Unit 1000 - Neuroimaging & Psychiatry, Maison de Solenn
# *Mattay
# *Anand.mattay@libd.org
# *Kwok
# *John.kwok@sydney.edu.au
# *Thalamuthu
# *A.thalamuthu@unsw.edu.au
# *ADMRI Sample Data
# *File:ADMRI.xlsx
# *DiskTestADMRI
# *University of Nottingham
# *Notts
# *Postboks4956Nydalen424
# *HasResearchInterests (E)
# *HasCountry (E)
# *Neuroscience Graduate Program
# *Technological Facilities. Valdecilla Biomedical Research Institute IDIVAL
# *University of Cantabria-IDIVAL
# *Institute for Molecular Biosciences
# *PTSD WG
# *Morey Raj
# *Logue Mark
# *University of Texas Rio Grande Valley
# *HasLastName (E)
# *Radboud University
# *Chakravarty Mallar
# *Chakravarty
# *Mallar@cobralab.ca
# *Department of Psychology-UO
# *UK Dementia Research Institute at the University of Edinburgh
# *MargareteHoeppelPlatz197080
# *Vermont5405
# *Sommer
# *I.e.c.sommer@umcg.nl
# *Strike
# *L.strike1@uq.edu.au
# *HasPBriefDescription (E)
# *Sim
# *Kang sim@imh.com.sg
# *Mathalon
# *Daniel.mathalon@ucsf.edu
# *University of Melbourne Academic Unit for Psychiatry of Old Age
# *NormanbyHouseStGeorge'sHospital283CothamRdVictoria3101
# *BD WG
# *Academic Medical Center (AMC)
# *Grupo de Investigación en Psiquiatría (GIPSI)
# *IMPACT
# *International Group for The Study of Lithium Treated Patients (IGSLi)
# *Singapore Cross Diagnostic Study
# *Psychosis Clinical Academic Group
# *Mood and Brain Lab
# *BD DTI Machine Learning
# *BD Hippocampal Subfields
# *BD Subcortical Shape
# *BD Brain Aging
# *BD Cortical
# *BD Subcortical
# *BD Structural Machine Learning
# *Karama
# *Sherif.karama@mcgill.ca
# *Bernd.kraemer@med-uni-heidelberg.dee
# *Department of Psychiatry, Psychosomatics and Psychotherapy
# *University Clinic of Wuerzburg
# *Department of Radiology and Nuclear Medicine
# *PrinsesseKristinasv57030
# *NPIEuroaCentrePrinceofWalesHospitalBarkerStreetNewSouthWales2031
# *Roth Mota
# *Nina.RothMota@radboudumc.nl
# *Department of Neurology-JHU
# *Zhu
# *Alyssa.Zhu@loni.usc.edu
# *Hottenga
# *Jj.jhottenga@vu.nl
# *Max-Planck-Institute of Psychiatry
# *Queensland Brain Institute
# *Building79Queensland4072
# *School of Psychiatry-UNSW
# *Lee
# *PLEE0@mgh.harvard.edu
# *Queensland University of Technology
# *Queensland4072
# *OA.vandenHeuvel@vumc.nl
# *HasWGSpecialContributor (E)
# *UC Irvine Neuropsychiatric Center
# *Milaneschi yuri
# *Milaneschi
# *Y.milaneschi@ggzingeest.nl
# *ORIGINs WG
# *Knickmeyer Rebecca
# *Institute of Clinical Medicine
# *808RoutedeLennik1070
# *Reppermund
# *S.reppermund@unsw.edu.au
# *Mather
# *Karen.mather@unsw.edu.au
# *EOP WG
# *LeftOnDate (E)
# *Thomopoulos
# *Sophia.Thomopoulos@loni.usc.edu
# *StellenboschCentral7599
# *IMAGEN Sample Data
# *File:IMAGEN.xlsx
# *DiskTestIMAGEN
# *Wen
# *W.wen@unsw.edu.au
# *CIDI interview
# *Major Depressive Disorder
# *FreeSurfer5.1
# *Transgender WG
# *Luders Elieen
# *Mueller Sven
# *Posthuma
# *D.posthuma@vu.nl
# *Department of Psychiatry-ISMMS
# *WithMinAgeOfOnsetOfDisorder (E)
# *Westlye
# *Westlye Lars
# *L.t.westlye@psykologi.uio.no
# *Dohm
# *Katharina.Dohm@ukmuenster.de
# *Sachdev
# *P.sachdev@unsw.edu.au
# *Knapp
# *Knapp@uni-bonn.de
# *SulciWG
# *Steen
# *Vidar.martin.steen@helse-bergen.no
# *Gutman
# *Gutman Boris
# *Bgutman@gmail.com
# *Zhou
# *Helen.zhou@duke-nus.edu.sg
# *Sir Peter Mansfield Imaging Centre
# *UniversityParkNottsNG72RD
# *CollegeGreen
# *Neurology and Neurosurgery Department
# *The Hospital for Sick Children
# *Turner Jessica
# *Mueller
# *Muell093@umn.edu
# *McConnell Brain Imaging Center
# *Departments of Psychiatry and Radiology
# *UCL Institute of Neurology
# *QueenSquareWC1N3BG
# *University College London
# *ShapeWG
# *RsfMRI WG
# *Adhikari Bhim
# *Kochunov Peter
# *Karakter Child and Adolescent Psychiatry University Center
# *Tokyo Institute of Technology
# *IsCohortInWorkingGroup (E)
# *Zsembik
# *Leo.zsembik@unc.edu
# *Rotman Research Institute
# *VA San Francisco Healthcare System
# *HasPSpecialContributor (E)
# *HasMaxAge (E)
# *Rondebosch7700
# *Kasperaviciute
# *Dalia.kasperaviciute@genomicsengland.co.uk
# *Hibar
# *Hibar Derrek
# *Dhibar@gmail.com
# *ADHD WG
# *HasMOU (E)
# ...
# *HMS grp SCZ proj PositiveSymptoms SCZ
# *Dublin grp SCZ proj PositiveSymptoms SCZ
# *Edinburgh (SFMH) grp SCZ proj PositiveSymptoms SCZ
# *FBIRN (Phase3) grp SCZ proj PositiveSymptoms SCZ
# *Galway grp SCZ proj PositiveSymptoms SCZ
# *HUBIN grp SCZ proj PositiveSymptoms SCZ
# *KaSP grp SCZ proj PositiveSymptoms SCZ
# *PAFIP grp SCZ proj PositiveSymptoms SCZ
# *TOP grp SCZ proj PositiveSymptoms SCZ
# *UMCU grp SCZ proj PositiveSymptoms SCZ
# *UPENN grp SCZ proj PositiveSymptoms SCZ
# *MCIC grp SCZ proj PositiveSymptoms SCZ
# *ROMA S.Lucia grp SCZ proj PositiveSymptoms SCZ
# *OSAKA grp SCZ proj PositiveSymptoms SCZ
# *UMCU SOMMER grp SCZ proj PositiveSymptoms SCZ
# *UNIBA grp SCZ proj PositiveSymptoms SCZ
# *Basel SCORE grp HC proj SubcorticalShape SCZ
# *CAMH grp HC proj SubcorticalShape SCZ
# *CIAM grp HC proj SubcorticalShape SCZ
# *Dublin grp HC proj SubcorticalShape SCZ
# *FBIRN grp HC proj SubcorticalShape SCZ
# *FIDMAG grp HC proj SubcorticalShape SCZ
# *Galway grp HC proj SubcorticalShape SCZ
# *Hubin grp HC proj SubcorticalShape SCZ
# *Indiana grp HC proj SubcorticalShape SCZ
# *KASP grp HC proj SubcorticalShape SCZ
# *MCIC grp HC proj SubcorticalShape SCZ
# *MPRC grp HC proj SubcorticalShape SCZ
# *NARSAD grp HC proj SubcorticalShape SCZ
# *NU grp HC proj SubcorticalShape SCZ
# *Olin grp HC proj SubcorticalShape SCZ
# *Oxford grp HC proj SubcorticalShape SCZ
# *PAFIP GE grp HC proj SubcorticalShape SCZ
# *PAFIP Phil grp HC proj SubcorticalShape SCZ
# *R SCZ grp HC proj SubcorticalShape SCZ
# *SLF Rome grp HC proj SubcorticalShape SCZ
# *TOP grp HC proj SubcorticalShape SCZ
# *UCISZ grp HC proj SubcorticalShape SCZ
# *UPenn grp HC proj SubcorticalShape SCZ
# *Wellcome grp HC proj SubcorticalShape SCZ
# *Basel SCORE grp SCZ proj SubcorticalShape SCZ
# *CAMH grp SCZ proj SubcorticalShape SCZ
# *CIAM grp SCZ proj SubcorticalShape SCZ
# *Dublin grp SCZ proj SubcorticalShape SCZ
# *FBIRN grp SCZ proj SubcorticalShape SCZ
# *FIDMAG grp SCZ proj SubcorticalShape SCZ
# *Galway grp SCZ proj SubcorticalShape SCZ
# *Hubin grp SCZ proj SubcorticalShape SCZ
# *Indiana grp SCZ proj SubcorticalShape SCZ
# *KASP grp SCZ proj SubcorticalShape SCZ
# *MCIC grp SCZ proj SubcorticalShape SCZ
# *MPRC grp SCZ proj SubcorticalShape SCZ
# *NARSAD grp SCZ proj SubcorticalShape SCZ
# *NU grp SCZ proj SubcorticalShape SCZ
# *Olin grp SCZ proj SubcorticalShape SCZ
# *Oxford grp SCZ proj SubcorticalShape SCZ
# *PAFIP GE grp SCZ proj SubcorticalShape SCZ
# *PAFIP Phil grp SCZ proj SubcorticalShape SCZ
# *R SCZ grp SCZ proj SubcorticalShape SCZ
# *SLF Rome grp SCZ proj SubcorticalShape SCZ
# *TOP grp SCZ proj SubcorticalShape SCZ
# *UCISZ grp SCZ proj SubcorticalShape SCZ
# *UPenn grp SCZ proj SubcorticalShape SCZ
# *Wellcome grp SCZ proj SubcorticalShape SCZ
# *AMC proj Cortical SCZ
# *Proj Cortical SCZ
# *AMC proj Subcortical SCZ
# *Proj Subcortical SCZ
# *ASRB proj Cortical SCZ
# *Basel SCORE proj SubcorticalShape SCZ
# *Proj SubcorticalShape SCZ
# *CAIM proj SubcorticalShape SCZ
# *CAIM
# *CAMH proj Cortical SCZ
# *CAMH proj SubcorticalShape SCZ
# *CIAM proj Cortical SCZ
# *CliNG proj PositiveSymptoms SCZ
# *Proj PositiveSymptoms SCZ
# *COBRE proj Cortical SCZ
# *Dublin proj NegativeSymptoms SCZ
# *Dublin proj PositiveSymptoms SCZ
# *Dublin proj SubcorticalShape SCZ
# *Edinburgh (SFMH) proj NegativeSymptoms SCZ
# *Edinburgh (SFMH) proj PositiveSymptoms SCZ
# *Edinburgh proj Subcortical SCZ
# *EdinburghEHRS proj Cortical SCZ
# *EdinburghFunc proj Cortical SCZ
# *EdinburghSFMH proj Cortical SCZ
# *ESO proj Cortical SCZ
# *FBIRN (Phase3) proj NegativeSymptoms SCZ
# *FBIRN (Phase3) proj PositiveSymptoms SCZ
# *FBIRN proj Cortical SCZ
# *FBIRN proj Subcortical SCZ
# *FBIRN proj SubcorticalShape SCZ
# *FIDMAG proj Cortical SCZ
# *FIDMAG proj SubcorticalShape SCZ
# *Frankfurt proj Cortical SCZ
# *Galway proj Cortical SCZ
# *Galway proj NegativeSymptoms SCZ
# *Galway proj PositiveSymptoms SCZ
# *Galway proj Subcortical SCZ
# *Galway proj SubcorticalShape SCZ
# *GAP proj Cortical SCZ
# *HMS proj Cortical SCZ
# *HMS proj NegativeSymptoms SCZ
# *HMS proj PositiveSymptoms SCZ
# *HMS proj Subcortical SCZ
# *HUBIN proj Cortical SCZ
# *HUBIN proj NegativeSymptoms SCZ
# *HUBIN proj PositiveSymptoms SCZ
# *HUBIN proj Subcortical SCZ
# *Hubin proj SubcorticalShape SCZ
# *Huilong1 proj Cortical SCZ
# *Huilong2 proj Cortical SCZ
# *Indiana proj SubcorticalShape SCZ
# *KaSP proj Cortical SCZ
# *KaSP proj NegativeSymptoms SCZ
# *KaSP proj PositiveSymptoms SCZ
# *KASP proj SubcorticalShape SCZ
# *MCIC proj Cortical SCZ
# *MCIC proj NegativeSymptoms SCZ
# *MCIC proj PositiveSymptoms SCZ
# *MCIC proj Subcortical SCZ
# *MCIC proj SubcorticalShape SCZ
# *MPRC proj SubcorticalShape SCZ
# *MPRC1 proj Cortical SCZ
# *MPRC2 proj Cortical SCZ
# *NARSAD proj SubcorticalShape SCZ
# *NU proj Cortical SCZ
# *NU proj Subcortical SCZ
# *NU proj SubcorticalShape SCZ
# *OLIN proj Cortical SCZ
# *Olin proj Subcortical SCZ
# *Olin proj SubcorticalShape SCZ
# *Osaka proj Cortical SCZ
# *OSAKA proj NegativeSymptoms SCZ
# *OSAKA proj PositiveSymptoms SCZ
# *Oxford proj SubcorticalShape SCZ
# *PAFIP GE proj SubcorticalShape SCZ
# *PAFIP proj NegativeSymptoms SCZ
# *PAFIP proj PositiveSymptoms SCZ
# *PAFIP proj Subcortical SCZ
# *PAFIP1.5T proj Cortical SCZ
# *PAFIP3T proj Cortical SCZ
# *R SCZ proj SubcorticalShape SCZ
# *RAFIP Phil proj SubcorticalShape SCZ
# *RAFIP Phil
# *ROMA S.Lucia proj NegativeSymptoms SCZ
# *ROMA S.Lucia proj PositiveSymptoms SCZ
# *RomeSL proj Cortical SCZ
# *RSCZ proj Cortical SCZ
# *SaoPaulo proj Cortical SCZ
# *SCORE proj Cortical SCZ
# *SLF Rome proj SubcorticalShape SCZ
# *SLF Rome
# *SNUH proj Cortical SCZ
# *TOP proj Cortical SCZ
# *TOP proj NegativeSymptoms SCZ
# *TOP proj PositiveSymptoms SCZ
# *TOP proj Subcortical SCZ
# *TOP proj SubcorticalShape SCZ
# *UCISZ proj SubcorticalShape SCZ
# *UMCU proj Cortical SCZ
# *UMCU proj NegativeSymptoms SCZ
# *UMCU proj PositiveSymptoms SCZ
# *UMCU proj Subcortical SCZ
# *UMCU SOMMER proj NegativeSymptoms SCZ
# *UMCU SOMMER proj PositiveSymptoms SCZ
# *UMCUS proj Cortical SCZ
# *UNIBA proj Cortical SCZ
# *UNIBA proj NegativeSymptoms SCZ
# *UNIBA proj PositiveSymptoms SCZ
# *UPENN proj Cortical SCZ
# *UPENN proj NegativeSymptoms SCZ
# *UPENN proj PositiveSymptoms SCZ
# *UPENN proj Subcortical SCZ
# *UPenn proj SubcorticalShape SCZ
# *Wellcome proj SubcorticalShape SCZ
# *1000BRAINS ENIGMA3 Cortical GWAS Results
# *File:1000BRAINS Significant GWAS.csv
# *Http://organicdatacuration.org/enigma new/index.php/File:1000BRAINS Significant GWAS.csv
# *ADNI1 ENIGMA3 Cortical GWAS Results
# *ADNI2GO ENIGMA3 Cortical GWAS Results
# *File:ADNI2GO Significant GWAS.csv
# *ALSPACa ENIGMA3 Cortical GWAS Results
# *File:ALSPAC Significant GWAS.csv
# *ASRB ENIGMA3 Cortical GWAS Results
# *File:ASRB Significant GWAS.csv
# *File:BETULA Significant GWAS.csv
# *BETULA ENIGMA3 Cortical GWAS Results
# *BIG-Affy ENIGMA3 Cortical GWAS Results
# *File:BIG Significant GWAS.csv
# *Bipolar Disorder WG
# *ENIGMA Highlights
# *Wenhao Jian
# *Erlich Stephan
# *Gur Ruben
# *Nickl-Jockschat Thomas
# *Ting-Yat
# *Kong Xiangzhen
# *Van Haren Neeltje
# *De Zwarte Sonja
# *Patel Yash
# *Radua Joaquim
# *Wang Lei
# *Young-Chul Chung, Woo Sung Kim
# *Holleran Laurena
# *Donohoe Gary
# *Spalletta Gianfranco
# *Banaj Nerisa
# *Erlich Stefan
# *Schmaal Lianna
# *Andreassen Ole
# *Ching Chris
# *Thompson Paul
# *Tordesillas Diana
# *Ciufolini Simone
# *Medland Sara
# *Petrov Dmitry
# *Jalbrzikowsk Mariai
# *Hernaus Dennis
# *Hajek Tomas
# *Sawa Akira
# *Yang Kun
# *Bernard Jessica
# *Pergola Gary
# *Zalesky Andrew
# *Koenders Laura
# *Modinos Gemma
# *Aleman Andre
# *File:BIG-PsychChip Significant GWAS.csv
# *BIG-PsychChip ENIGMA3 Cortical GWAS Results
# *BONN ENIGMA3 Cortical GWAS Results
# *BrainScale ENIGMA3 Cortical GWAS Results
# *File:BrainScale Significant GWAS.csv
# *File:CARDIFF Significant GWAS.csv
# *CARDIFF ENIGMA3 Cortical GWAS Results
# *File:DNS-V3 Significant GWAS.csv
# *DNS-V3 ENIGMA3 Cortical GWAS Results
# *File:DNS-V4 Significant GWAS.csv
# *DNS-V4 ENIGMA3 Cortical GWAS Results
# *EPIGEN ENIGMA3 Cortical GWAS Results
# *File:EPIGEN Significant GWAS.csv
# *FBIRN ENIGMA3 Cortical GWAS Results
# *File:FBIRN Significant GWAS.csv
# *File:FOR2107 Significant GWAS.csv
# *FOR2107 ENIGMA3 Cortical GWAS Results
# *File:GIG Significant GWAS.csv
# *GIG ENIGMA3 Cortical GWAS Results
# *File:GOBS Significant GWAS.csv
# *GOBS ENIGMA3 Cortical GWAS Results
# *File:GSP Significant GWAS.csv
# *GSP ENIGMA3 Cortical GWAS Results
# *File:HUBIN Significant GWAS.csv
# *HUBIN ENIGMA3 Cortical GWAS Results
# *File:HUNT Significant GWAS.csv
# *HUNT ENIGMA3 Cortical GWAS Results
# *File:IMAGEN Significant GWAS.csv
# *IMAGEN ENIGMA3 Cortical GWAS Results
# *File:IMH Significant GWAS.csv
# *IMH ENIGMA3 Cortical GWAS Results
# *File:ImpACT Significant GWAS.csv
# *IMpACT ENIGMA3 Cortical GWAS Results
# *File:LBC1936 Significant GWAS.csv
# *LBC1936 ENIGMA3 Cortical GWAS Results
# *File:LIBD Significant GWAS.csv
# *LIBD ENIGMA3 Cortical GWAS Results
# *File:MCIC Significant GWAS.csv
# *MCIC ENIGMA3 Cortical GWAS Results
# *File:Meth-CT Significant GWAS.csv
# *Meth-CT ENIGMA3 Cortical GWAS Results
# *File:MIRECC Significant GWAS.csv
# *MIRECC ENIGMA3 Cortical GWAS Results
# *File:MooDS Significant GWAS.csv
# *MooDS ENIGMA3 Cortical GWAS Results
# *Http://organicdatacuration.org/enigma new/index.php/File:MooDS Significant GWAS.csv
# *DataDownload(E)
# *File:MPIP Significant GWAS.csv
# *MPIP ENIGMA3 Cortical GWAS Results
# *File:MPRC Significant GWAS.csv
# *MPRC ENIGMA3 Cortical GWAS Results
# *File:MUNSTER Significant GWAS.csv
# *MUNSTER ENIGMA3 Cortical GWAS Results
# *File:NCNG Significant GWAS.csv
# *NCNG ENIGMA3 Cortical GWAS Results
# *File:NESDA Significant GWAS.csv
# *NESDA ENIGMA3 Cortical GWAS Results
# *File:NeuroIMAGE Significant GWAS.csv
# *NeuroIMAGE ENIGMA3 Cortical GWAS Results
# *File:NTR Significant GWAS.csv
# *NTR ENIGMA3 Cortical GWAS Results
# *File:OATS Significant GWAS.csv
# *OATS ENIGMA3 Cortical GWAS Results
# *File:OSAKA Significant GWAS.csv
# *OSAKA ENIGMA3 Cortical GWAS Results
# *File:PAFIP Significant GWAS.csv
# *PAFIP ENIGMA3 Cortical GWAS Results
# *File:PDNZ Significant GWAS.csv
# *PDNZ ENIGMA3 Cortical GWAS Results
# *File:PING NonEuropean Significant GWAS.csv
# *PING-nonEUR ENIGMA3 Cortical GWAS Results
# *File:PING Significant GWAS.csv
# *PING ENIGMA3 Cortical GWAS Results
# *File:PPMI Significant GWAS.csv
# *PPMI ENIGMA3 Cortical GWAS Results
# *File:QTIM Significant GWAS.csv
# *QTIM ENIGMA3 Cortical GWAS Results
# *File:SHIP Significant GWAS.csv
# *SHIP ENIGMA3 Cortical GWAS Results
# *File:SHIP-Trend Significant GWAS.csv
# *SHIP-Trend ENIGMA3 Cortical GWAS Results
# *File:SydneyMAS Significant GWAS.csv
# *Sydney MAS ENIGMA3 Cortical GWAS Results
# *File:SYS Significant GWAS.csv
# *SYS ENIGMA3 Cortical GWAS Results
# *File:TCD-NUIG Significant GWAS.csv
# *TCD-NUIG ENIGMA3 Cortical GWAS Results
# *File:TOP Significant GWAS.csv
# *TOP ENIGMA3 Cortical GWAS Results
# *File:TOP3T Significant GWAS.csv
# *TOP3T ENIGMA3 Cortical GWAS Results
# *File:UiO2016 Significant GWAS.csv
# *UiO2016 ENIGMA3 Cortical GWAS Results
# *File:UiO2017 Significant GWAS.csv
# *UiO2017 ENIGMA3 Cortical GWAS Results
# *File:UKBB NonEuropean Significant GWAS.csv
# *UKBB-nonEUR ENIGMA3 Cortical GWAS Results
# *File:UKBB Significant GWAS.csv
# *UKBB ENIGMA3 Cortical GWAS Results
# *File:UMCU Significant GWAS.csv
# *UMCU ENIGMA3 Cortical GWAS Results
# *File:UNICAMP Significant GWAS.csv
# *UNICAMP ENIGMA3 Cortical GWAS Results
# *File:ADNI1 Significant GWAS.csv
# *SCZ Landing Page
# *New Cohort
# *Www.google.com
# *Www.yahoo.com
# *Http://www.yahoo.com
# *Proj Network Modeling
# *Proj Social Economic Status
# *Fabrizio Pizzagali
# *Woo Sung Kim
# *Young-Chul Chung
# *Proj Genotyping
# *Https://doi.org/10.1016/j.biopsych.2018.04.023
# *Https://drive.google.com/drive/folders/1WB0hl8xjwnqO2YpNSuJd1aE0DsIvnUvA
# *Https://pubmed.ncbi.nlm.nih.gov/28545597/
# *Https://pubmed.ncbi.nlm.nih.gov/28369804/
# *Https://pubmed.ncbi.nlm.nih.gov/31443932/
# *Https://pubmed.ncbi.nlm.nih.gov/31615588/
# *Https://pubmed.ncbi.nlm.nih.gov/29038599/
# *Https://pubmed.ncbi.nlm.nih.gov/27738994/
# *Https://pubmed.ncbi.nlm.nih.gov/32193296/
# *Https://pubmed.ncbi.nlm.nih.gov/28580697/
# *Https://pubmed.ncbi.nlm.nih.gov/29764998/
# *Https://pubmed.ncbi.nlm.nih.gov/32212855/
# *Https://arxiv.org/abs/1808.10315
# *Https://pubmed.ncbi.nlm.nih.gov/32470572/
# *JOSH COHORT
# *Example Queries
# *File:AddictionAlcohol.png
# *File:ADHD.png
# *File:BipolarDisorder.png
# *File:DepressionMDD.png
# *File:OCD.png
# *File:Schizophrenia.png
# {'head': {'vars': ['a']}, 'results': {'bindings': [{'a': {'type': 'literal', 'value': 'Foaf:knows'}}, {'a': {'type': 'literal', 'value': 'Pages with ignored display titles'}}, {'a': {'type': 'literal', 'value': 'Imported vocabulary'}}, {'a': {'type': 'literal', 'value': 'Has processing error'}}, {'a': {'type': 'literal', 'value': 'Modification date'}}, {'a': {'type': 'literal', 'value': 'Has property description'}}, {'a': {'type': 'literal', 'value': 'Has improper value for'}}, {'a': {'type': 'literal', 'value': ' IMPO'}}, {'a': {'type': 'literal', 'value': 'Has processing error text'}}, {'a': {'type': 'literal', 'value': 'Language code'}}, {'a': {'type': 'literal', 'value': 'Text'}}, {'a': {'type': 'literal', 'value': 'Foaf:name'}}, {'a': {'type': 'literal', 'value': 'Foaf:homepage'}}, {'a': {'type': 'literal', 'value': 'Owl:differentFrom'}}, {'a': {'type': 'literal', 'value': 'HasCity (E)'}}, {'a': {'type': 'literal', 'value': 'Has multiple values'}}, {'a': {'type': 'literal', 'value': 'True'}}, {'a': {'type': 'literal', 'value': 'HasConsortium'}}, {'a': {'type': 'literal', 'value': 'UsesDiagnosisInstrument (E)'}}, {'a': {'type': 'literal', 'value': 'Has page category'}}, {'a': {'type': 'literal', 'value': 'DiagnosisInstrument (E)'}}, {'a': {'type': 'literal', 'value': 'ObtainedInformationThrough (E)'}}, {'a': {'type': 'literal', 'value': 'InformationObtainmentMethod (E)'}}, {'a': {'type': 'literal', 'value': 'HasLocationOfDataCollection (E)'}}, {'a': {'type': 'literal', 'value': 'Location (E)'}}, {'a': {'type': 'literal', 'value': 'Has User ID'}}, {'a': {'type': 'literal', 'value': 'HasFirstAuthor'}}, {'a': {'type': 'literal', 'value': 'HasLastAuthor (E)'}}, {'a': {'type': 'literal', 'value': 'Hypothesis (E)'}}, {'a': {'type': 'literal', 'value': 'HasAuthorRulesPage (E)'}}, {'a': {'type': 'literal', 'value': 'HasFirstAuthor2 (E)'}}, {'a': {'type': 'literal', 'value': 'HasFirstAuthor (E)'}}, {'a': {'type': 'literal', 'value': 'Http://organicdatacuration.org/enigma new/index.php/Special:authorGeneration?project=ENIGMA3 Cortical GWAS'}}, {'a': {'type': 'literal', 'value': 'HasAuthorGenerationPage (E)'}}, {'a': {'type': 'literal', 'value': 'HasFirstDegreeRelativeWithDisorder (E)'}}, {'a': {'type': 'literal', 'value': 'Disorder (E)'}}, {'a': {'type': 'literal', 'value': 'HasFamilyHistoryOf (E)'}}, {'a': {'type': 'literal', 'value': 'HasDiagnosisInstrument (E)'}}, {'a': {'type': 'literal', 'value': 'HasDisorderDetails (E)'}}, {'a': {'type': 'literal', 'value': 'SpecificDisorderInfo (E)'}}, {'a': {'type': 'literal', 'value': 'DoesNotHaveFirstDegreeRelativeWithDisorder (E)'}}, {'a': {'type': 'literal', 'value': 'Disjoint with'}}, {'a': {'type': 'literal', 'value': 'DoesNotHaveFamilyHistoryOf (E)'}}, {'a': {'type': 'literal', 'value': 'UsesTreatment (E)'}}, {'a': {'type': 'literal', 'value': 'Treatment (E)'}}, {'a': {'type': 'literal', 'value': 'HasInformationMethod (E)'}}, {'a': {'type': 'literal', 'value': 'HasMembersWithRecentIssue (E)'}}, {'a': {'type': 'literal', 'value': 'Condition (E)'}}, {'a': {'type': 'literal', 'value': 'DoesNotUseTreatment (E)'}}, {'a': {'type': 'literal', 'value': 'HasPersonalHistoryOf (E)'}}, {'a': {'type': 'literal', 'value': 'DoesNotHaveDisorder (E)'}}, {'a': {'type': 'literal', 'value': 'HasDisorder (E)'}}, {'a': {'type': 'literal', 'value': 'UsesGenotypePlatform (E)'}}, {'a': {'type': 'literal', 'value': 'GenotypePlatform (E)'}}, {'a': {'type': 'literal', 'value': 'HasCondition (E)'}}, {'a': {'type': 'literal', 'value': 'HasFirstEpisodeOf (E)'}}, {'a': {'type': 'literal', 'value': 'HasTreatmentDetails (E)'}}, {'a': {'type': 'literal', 'value': 'SpecificTreatmentInfo (E)'}}, {'a': {'type': 'literal', 'value': 'DoesNotHaveCondition (E)'}}, {'a': {'type': 'literal', 'value': 'DidNotHaveFirstEpisodeOf (E)'}}, {'a': {'type': 'literal', 'value': 'DoesNotHavePersonalHistoryOf (E)'}}, {'a': {'type': 'literal', 'value': 'FulfillsDiagnosticCriteria (E)'}}, {'a': {'type': 'literal', 'value': 'DiagnosticCriteri ...

# %% [markdown]
# This following query shows us all of the different Working Groups which exist in the wiki along with the cohorts associated with them.

# %%
#Show all the working groups with their cohorts

url = "http://linkedearth.isi.edu:3030/db"
replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"

query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?w ?a
WHERE 
{
    # ?w wiki:Property-3AHasCohort_-28E-29 ?a.
}
ORDER BY ?w"""


response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

#print(res)
print("Working Groups with Cohorts:")    
for item in res['results']['bindings']:
     print ("*" + item['w']['value'].replace(replace,"")+" has cohort:" + item['a']['value'].replace(replace,""))
# Out:
# Working Groups with Cohorts:
# *BD_WG has cohort:Academic_Medical_Center_-28AMC-29
# *BD_WG has cohort:Bipolar_Family_Study_-28BFS-29
# *BD_WG has cohort:CIAM
# *BD_WG has cohort:CLING
# *BD_WG has cohort:Cardiff
# *BD_WG has cohort:FIDMAG
# *BD_WG has cohort:Grupo_de_Investigaci-C3-B3n_en_Psiquiatr-C3-ADa_-28GIPSI-29
# *BD_WG has cohort:IMPACT
# *BD_WG has cohort:International_Group_for_The_Study_of_Lithium_Treated_Patients_-28IGSLi-29
# *BD_WG has cohort:Mood_and_Brain_Lab
# *BD_WG has cohort:Psychosis_Clinical_Academic_Group
# *BD_WG has cohort:Singapore_Cross_Diagnostic_Study
# *BPD_WG has cohort:Academic_Medical_Center_-28AMC-29
# *BPD_WG has cohort:Bipolar_Family_Study_-28BFS-29
# *BPD_WG has cohort:CIAM
# *BPD_WG has cohort:CLING
# *BPD_WG has cohort:Cardiff
# *BPD_WG has cohort:FIDMAG
# *BPD_WG has cohort:Grupo_de_Investigaci-C3-B3n_en_Psiquiatr-C3-ADa_-28GIPSI-29
# *BPD_WG has cohort:IMPACT
# *BPD_WG has cohort:International_Group_for_The_Study_of_Lithium_Treated_Patients_-28IGSLi-29
# *BPD_WG has cohort:Mood_and_Brain_Lab
# *BPD_WG has cohort:Psychosis_Clinical_Academic_Group
# *BPD_WG has cohort:Singapore_Cross_Diagnostic_Study
# *ENIGMA3_Cortical_GWAS has cohort:1000BRAINS
# *ENIGMA3_Cortical_GWAS has cohort:ADNI
# *ENIGMA3_Cortical_GWAS has cohort:ADNI1
# *ENIGMA3_Cortical_GWAS has cohort:ADNI2GO
# *ENIGMA3_Cortical_GWAS has cohort:ALSPACa
# *ENIGMA3_Cortical_GWAS has cohort:ASRB
# *ENIGMA3_Cortical_GWAS has cohort:BETULA
# *ENIGMA3_Cortical_GWAS has cohort:BIG-2DAffy
# *ENIGMA3_Cortical_GWAS has cohort:BIG-2DPsychChip
# *ENIGMA3_Cortical_GWAS has cohort:BONN
# *ENIGMA3_Cortical_GWAS has cohort:BRIDGE
# *ENIGMA3_Cortical_GWAS has cohort:BrainScale
# *ENIGMA3_Cortical_GWAS has cohort:CARDIFF
# *ENIGMA3_Cortical_GWAS has cohort:CHARGE_Replication_Cohort
# *ENIGMA3_Cortical_GWAS has cohort:CHOP
# *ENIGMA3_Cortical_GWAS has cohort:DNS-2DV3
# *ENIGMA3_Cortical_GWAS has cohort:DNS-2DV4
# *ENIGMA3_Cortical_GWAS has cohort:EPIGEN
# *ENIGMA3_Cortical_GWAS has cohort:FBIRN
# *ENIGMA3_Cortical_GWAS has cohort:FOR2107
# *ENIGMA3_Cortical_GWAS has cohort:GIG
# *ENIGMA3_Cortical_GWAS has cohort:GOBS
# *ENIGMA3_Cortical_GWAS has cohort:GROUP
# *ENIGMA3_Cortical_GWAS has cohort:GSP
# *ENIGMA3_Cortical_GWAS has cohort:HUBIN
# *ENIGMA3_Cortical_GWAS has cohort:HUNT
# *ENIGMA3_Cortical_GWAS has cohort:ID1000
# *ENIGMA3_Cortical_GWAS has cohort:ID1000_Replication_Cohort
# *ENIGMA3_Cortical_GWAS has cohort:IGC
# *ENIGMA3_Cortical_GWAS has cohort:IMAGEN
# *ENIGMA3_Cortical_GWAS has cohort:IMH
# *ENIGMA3_Cortical_GWAS has cohort:IMpACT
# *ENIGMA3_Cortical_GWAS has cohort:LBC1936
# *ENIGMA3_Cortical_GWAS has cohort:LIBD
# *ENIGMA3_Cortical_GWAS has cohort:MAS
# *ENIGMA3_Cortical_GWAS has cohort:MCIC
# *ENIGMA3_Cortical_GWAS has cohort:MIRECC
# *ENIGMA3_Cortical_GWAS has cohort:MPIP
# *ENIGMA3_Cortical_GWAS has cohort:MPRC
# *ENIGMA3_Cortical_GWAS has cohort:MUNSTER
# *ENIGMA3_Cortical_GWAS has cohort:Meth-2DCT
# *ENIGMA3_Cortical_GWAS has cohort:MooDS
# *ENIGMA3_Cortical_GWAS has cohort:NCNG
# *ENIGMA3_Cortical_GWAS has cohort:NESDA
# *ENIGMA3_Cortical_GWAS has cohort:NTR
# *ENIGMA3_Cortical_GWAS has cohort:NTR-2DAdults
# *ENIGMA3_Cortical_GWAS has cohort:NeuroIMAGE
# *ENIGMA3_Cortical_GWAS has cohort:OATS
# *ENIGMA3_Cortical_GWAS has cohort:OSAKA
# *ENIGMA3_Cortical_GWAS has cohort:PAFIP
# *ENIGMA3_Cortical_GWAS has cohort:PDNZ
# *ENIGMA3_Cortical_GWAS has cohort:PING
# *ENIGMA3_Cortical_GWAS has cohort:PING-2DnonEUR
# *ENIGMA3_Cortical_GWAS has cohort:PPMI
# *ENIGMA3_Cortical_GWAS has cohort:QTIM
# *ENIGMA3_Cortical_GWAS has cohort:SHIP
# *ENIGMA3_Cortical_GWAS has cohort:SHIP-2DTrend
# *ENIGMA3_Cortical_GWAS has cohort:SYS
# *ENIGMA3_Cortical_GWAS has cohort:Sydney_MAS
# *ENIGMA3_Cortical_GWAS has cohort:TCD-2DNUIG
# *ENIGMA3_Cortical_GWAS has cohort:TOP
# *ENIGMA3_Cortical_GWAS has cohort:TOP3T
# *ENIGMA3_Cortical_GWAS has cohort:UKBB
# *ENIGMA3_Cortical_GWAS has cohort:UKBB-2DPRS
# *ENIGMA3_Cortical_GWAS has cohort:UKBB-2DnonEUR
# *ENIGMA3_Cortical_GWAS has cohort:UMCU
# *ENIGMA3_Cortical_GWAS has cohort:UMCU_-26_BrainSCALE
# *ENIGMA3_Cortical_GWAS has cohort:UNICAMP
# *ENIGMA3_Cortical_GWAS has cohort:UiO2016
# *ENIGMA3_Cortical_GWAS has cohort:UiO2017
# *MDD_WG has cohort:CLING
# *MDD_WG has cohort:Houston
# *MDD_WG has cohort:MPIP
# *MDD_WG has cohort:Oxford
# *MDD_WG has cohort:QTIM
# *MDD_WG has cohort:Sydney
# *Positive_Symptoms has cohort:CliNG
# *Positive_Symptoms has cohort:Dublin
# *Positive_Symptoms has cohort:Edinburgh_-28SFMH-29
# *Positive_Symptoms has cohort:FBIRN_-28Phase3-29
# *Positive_Symptoms has cohort:Galway
# *Positive_Symptoms has cohort:HMS
# *Positive_Symptoms has cohort:HUBIN
# *Positive_Symptoms has cohort:KaSP
# *Positive_Symptoms has cohort:MCIC
# *Positive_Symptoms has cohort:OSAKA
# *Positive_Symptoms has cohort:PAFIP
# *Positive_Symptoms has cohort:ROMA_S.Lucia
# *Positive_Symptoms has cohort:TOP
# *Positive_Symptoms has cohort:UMCU
# *Positive_Symptoms has cohort:UMCU_SOMMER
# *Positive_Symptoms has cohort:UNIBA
# *Positive_Symptoms has cohort:UPENN
# *Proj_APOE_test has cohort:ADNI1
# *Proj_APOE_test has cohort:ADNI2
# *Proj_APOE_test has cohort:AIBL
# *Proj_APOE_test has cohort:DLBS
# *Proj_APOE_test has cohort:UKBB
# *Proj_Cortical has cohort:AMC
# *Proj_Cortical has cohort:ASRB
# *Proj_Cortical has cohort:CAMH
# *Proj_Cortical has cohort:CIAM
# *Proj_Cortical has cohort:COBRE
# *Proj_Cortical has cohort:CliNG
# *Proj_Cortical has cohort:Dublin
# *Proj_Cortical has cohort:ESO
# *Proj_Cortical has cohort:EdinburghEHRS
# *Proj_Cortical has cohort:EdinburghFunc
# *Proj_Cortical has cohort:EdinburghSFMH
# *Proj_Cortical has cohort:FBIRN
# *Proj_Cortical has cohort:FIDMAG
# *Proj_Cortical has cohort:Frankfurt
# *Proj_Cortical has cohort:GAP
# *Proj_Cortical has cohort:Galway
# *Proj_Cortical has cohort:HMS
# *Proj_Cortical has cohort:HUBIN
# *Proj_Cortical has cohort:Huilong1
# *Proj_Cortical has cohort:Huilong2
# *Proj_Cortical has cohort:KaSP
# *Proj_Cortical has cohort:MCIC
# *Proj_Cortical has cohort:MPRC1
# *Proj_Cortical has cohort:MPRC2
# *Proj_Cortical has cohort:NU
# *Proj_Cortical has cohort:OLIN
# *Proj_Cortical has cohort:Osaka
# *Proj_Cortical has cohort:PAFIP1.5T
# *Proj_Cortical has cohort:PAFIP3T
# *Proj_Cortical has cohort:RSCZ
# *Proj_Cortical has cohort:RomeSL
# *Proj_Cortical has cohort:SCORE
# *Proj_Cortical has cohort:SNUH
# *Proj_Cortical has cohort:SaoPaulo
# *Proj_Cortical has cohort:TOP
# *Proj_Cortical has cohort:UMCU
# *Proj_Cortical has cohort:UMCUS
# *Proj_Cortical has cohort:UNIBA
# *Proj_Cortical has cohort:UPENN
# *Proj_DTI_IQ has cohort:ASRB
# *Proj_DTI_IQ has cohort:Asan_Medical_Center
# *Proj_DTI_IQ has cohort:Australia
# *Proj_DTI_IQ has cohort:Brain_and_Mind_Research_Institute
# *Proj_DTI_IQ has cohort:CAMH
# *Proj_DTI_IQ has cohort:CIAM_SouthAfrica
# *Proj_DTI_IQ has cohort:CIDAR/BWH
# *Proj_DTI_IQ has cohort:Dublin
# *Proj_DTI_IQ has cohort:Dublin_and_Galway
# *Proj_DTI_IQ has cohort:EQF
# *Proj_DTI_IQ has cohort:ESO_study
# *Proj_DTI_IQ has cohort:KASP
# *Proj_DTI_IQ has cohort:Mind_Research_Network
# *Proj_DTI_IQ has cohort:Olin
# *Proj_DTI_IQ has cohort:Osaka
# *Proj_DTI_IQ has cohort:PAFIP
# *Proj_DTI_IQ has cohort:Penn
# *Proj_DTI_IQ has cohort:Roma_S_Lucia
# *Proj_DTI_IQ has cohort:S-C3-A3o_Paulo1_-2D_ESTADO-2DNARSAD
# *Proj_DTI_IQ has cohort:SFMH
# *Proj_DTI_IQ has cohort:SNUH
# *Proj_DTI_IQ has cohort:SZ_Frankfurt
# *Proj_DTI_IQ has cohort:Sydney
# *Proj_DTI_IQ has cohort:UMCU
# *Proj_DTI_IQ has cohort:Umaryland_-28JHU_and_MPRC-29
# *Proj_DTI_IQ has cohort:Universidad_de_Antioquia
# *Proj_DTI_IQ has cohort:Upenn
# *Proj_DTI_IQ has cohort:Zurich
# *Proj_GWAS_Enigma_3 has cohort:ADNI
# *Proj_GWAS_Enigma_3 has cohort:BETULA
# *Proj_GWAS_Enigma_3 has cohort:BIG
# *Proj_GWAS_Enigma_3 has cohort:BIG-2DPsych
# *Proj_GWAS_Enigma_3 has cohort:BONN
# *Proj_GWAS_Enigma_3 has cohort:BRIDGE
# *Proj_GWAS_Enigma_3 has cohort:Brainscale
# *Proj_GWAS_Enigma_3 has cohort:CHOP
# *Proj_GWAS_Enigma_3 has cohort:Cardiff
# *Proj_GWAS_Enigma_3 has cohort:EPIGEN
# *Proj_GWAS_Enigma_3 has cohort:FBIRN
# *Proj_GWAS_Enigma_3 has cohort:FOR2107
# *Proj_GWAS_Enigma_3 has cohort:GIG
# *Proj_GWAS_Enigma_3 has cohort:GOBS
# *Proj_GWAS_Enigma_3 has cohort:GROUP
# *Proj_GWAS_Enigma_3 has cohort:GSP
# *Proj_GWAS_Enigma_3 has cohort:HUBIN
# *Proj_GWAS_Enigma_3 has cohort:HUNT
# *Proj_GWAS_Enigma_3 has cohort:ID1000
# *Proj_GWAS_Enigma_3 has cohort:IGC
# *Proj_GWAS_Enigma_3 has cohort:IMAGEN
# *Proj_GWAS_Enigma_3 has cohort:IMH
# *Proj_GWAS_Enigma_3 has cohort:IMpACT
# *Proj_GWAS_Enigma_3 has cohort:LBC1936
# *Proj_GWAS_Enigma_3 has cohort:LIBD
# *Proj_GWAS_Enigma_3 has cohort:MAS
# *Proj_GWAS_Enigma_3 has cohort:MCIC
# *Proj_GWAS_Enigma_3 has cohort:MPIP
# *Proj_GWAS_Enigma_3 has cohort:MUNSTER
# *Proj_GWAS_Enigma_3 has cohort:Meth-2DCT
# *Proj_GWAS_Enigma_3 has cohort:NCNG
# *Proj_GWAS_Enigma_3 has cohort:NESDA
# *Proj_GWAS_Enigma_3 has cohort:NTR-2DAdults
# *Proj_GWAS_Enigma_3 has cohort:NeuroIMAGE
# *Proj_GWAS_Enigma_3 has cohort:OATS
# *Proj_GWAS_Enigma_3 has cohort:Osaka
# *Proj_GWAS_Enigma_3 has cohort:PAFIP
# *Proj_GWAS_Enigma_3 has cohort:PING
# *Proj_GWAS_Enigma_3 has cohort:QTIM
# *Proj_GWAS_Enigma_3 has cohort:SHIP
# *Proj_GWAS_Enigma_3 has cohort:SHIP-2DTREND
# *Proj_GWAS_Enigma_3 has cohort:SYS
# *Proj_GWAS_Enigma_3 has cohort:TOP
# *Proj_GWAS_Enigma_3 has cohort:TOP3T
# *Proj_GWAS_Enigma_3 has cohort:UMCU
# *Proj_GWAS_Enigma_3 has cohort:UMCU_-26_BrainSCALE
# *Proj_Negative_Symptoms has cohort:CliNG
# *Proj_Negative_Symptoms has cohort:Dublin
# *Proj_Negative_Symptoms has cohort:Edinburgh_-28SFMH-29
# *Proj_Negative_Symptoms has cohort:FBIRN_-28Phase3-29
# *Proj_Negative_Symptoms has cohort:Galway
# *Proj_Negative_Symptoms has cohort:HMS
# *Proj_Negative_Symptoms has cohort:HUBIN
# *Proj_Negative_Symptoms has cohort:KaSP
# *Proj_Negative_Symptoms has cohort:MCIC
# *Proj_Negative_Symptoms has cohort:OSAKA
# *Proj_Negative_Symptoms has cohort:PAFIP
# *Proj_Negative_Symptoms has cohort:ROMA_S.Lucia
# *Proj_Negative_Symptoms has cohort:TOP
# *Proj_Negative_Symptoms has cohort:UMCU
# *Proj_Negative_Symptoms has cohort:UMCU_SOMMER
# *Proj_Negative_Symptoms has cohort:UNIBA
# *Proj_Negative_Symptoms has cohort:UPENN
# *Proj_Positive_Symptoms has cohort:CliNG
# *Proj_Positive_Symptoms has cohort:Dublin
# *Proj_Positive_Symptoms has cohort:Edinburgh_-28SFMH-29
# *Proj_Positive_Symptoms has cohort:FBIRN_-28Phase3-29
# *Proj_Positive_Symptoms has cohort:Galway
# *Proj_Positive_Symptoms has cohort:HMS
# *Proj_Positive_Symptoms has cohort:HUBIN
# *Proj_Positive_Symptoms has cohort:KaSP
# *Proj_Positive_Symptoms has cohort:MCIC
# *Proj_Positive_Symptoms has cohort:OSAKA
# *Proj_Positive_Symptoms has cohort:PAFIP
# *Proj_Positive_Symptoms has cohort:ROMA_S.Lucia
# *Proj_Positive_Symptoms has cohort:TOP
# *Proj_Positive_Symptoms has cohort:UMCU
# *Proj_Positive_Symptoms has cohort:UMCU_SOMMER
# *Proj_Positive_Symptoms has cohort:UNIBA
# *Proj_Positive_Symptoms has cohort:UPENN
# *Proj_Subcortical has cohort:AMC
# *Proj_Subcortical has cohort:CliNG
# *Proj_Subcortical has cohort:Dublin
# *Proj_Subcortical has cohort:Edinburgh
# *Proj_Subcortical has cohort:FBIRN
# *Proj_Subcortical has cohort:Galway
# *Proj_Subcortical has cohort:HMS
# *Proj_Subcortical has cohort:HUBIN
# *Proj_Subcortical has cohort:MCIC
# *Proj_Subcortical has cohort:NU
# *Proj_Subcortical has cohort:Olin
# *Proj_Subcortical has cohort:PAFIP
# *Proj_Subcortical has cohort:TOP
# *Proj_Subcortical has cohort:UMCU
# *Proj_Subcortical has cohort:UPENN
# *Proj_Subcortical_Shapes has cohort:Basel_SCORE
# *Proj_Subcortical_Shapes has cohort:CAMH
# *Proj_Subcortical_Shapes has cohort:CIAM
# *Proj_Subcortical_Shapes has cohort:Dublin
# *Proj_Subcortical_Shapes has cohort:FBIRN
# *Proj_Subcortical_Shapes has cohort:FIDMAG
# *Proj_Subcortical_Shapes has cohort:Galway
# *Proj_Subcortical_Shapes has cohort:Hubin
# *Proj_Subcortical_Shapes has cohort:Indiana
# *Proj_Subcortical_Shapes has cohort:KASP
# *Proj_Subcortical_Shapes has cohort:MCIC
# *Proj_Subcortical_Shapes has cohort:MPRC
# *Proj_Subcortical_Shapes has cohort:NARSAD
# *Proj_Subcortical_Shapes has cohort:NU
# *Proj_Subcortical_Shapes has cohort:Olin
# *Proj_Subcortical_Shapes has cohort:Oxford
# *Proj_Subcortical_Shapes has cohort:PAFIP_GE
# *Proj_Subcortical_Shapes has cohort:PAFIP_Phil
# *Proj_Subcortical_Shapes has cohort:R_SCZ
# *Proj_Subcortical_Shapes has cohort:StaLucia
# *Proj_Subcortical_Shapes has cohort:TOP
# *Proj_Subcortical_Shapes has cohort:UCISZ
# *Proj_Subcortical_Shapes has cohort:UPenn
# *Proj_Subcortical_Shapes has cohort:Wellcome
# *SZPositiveSymptoms has cohort:AMC
# *SZPositiveSymptoms has cohort:ASRB
# *SZPositiveSymptoms has cohort:CAMH
# *SZPositiveSymptoms has cohort:CIAM
# *SZPositiveSymptoms has cohort:CLING
# *SZPositiveSymptoms has cohort:COBRE
# *SZPositiveSymptoms has cohort:DublinDonohoe
# *SZPositiveSymptoms has cohort:ESO
# *SZPositiveSymptoms has cohort:EdinburghEHRS
# *SZPositiveSymptoms has cohort:EdinburghFunc
# *SZPositiveSymptoms has cohort:EdinburghSFMH
# *SZPositiveSymptoms has cohort:FBIRN
# *SZPositiveSymptoms has cohort:FIDMAG
# *SZPositiveSymptoms has cohort:FOR2107
# *SZPositiveSymptoms has cohort:Frankfurt
# *SZPositiveSymptoms has cohort:GAP
# *SZPositiveSymptoms has cohort:GIPSI
# *SZPositiveSymptoms has cohort:Galway
# *SZPositiveSymptoms has cohort:HMS
# *SZPositiveSymptoms has cohort:HUBIN
# *SZPositiveSymptoms has cohort:Huilong1
# *SZPositiveSymptoms has cohort:Huilong2
# *SZPositiveSymptoms has cohort:KASP
# *SZPositiveSymptoms has cohort:KaSP
# *SZPositiveSymptoms has cohort:MCIC
# *SZPositiveSymptoms has cohort:MPRC1
# *SZPositiveSymptoms has cohort:MPRC2
# *SZPositiveSymptoms has cohort:NU
# *SZPositiveSymptoms has cohort:OLIN
# *SZPositiveSymptoms has cohort:OsakaMR1
# *SZPositiveSymptoms has cohort:OsakaMR2
# *SZPositiveSymptoms has cohort:PAFIP1.5T
# *SZPositiveSymptoms has cohort:PAFIP3T
# *SZPositiveSymptoms has cohort:RSCZ
# *SZPositiveSymptoms has cohort:RomeSL
# *SZPositiveSymptoms has cohort:SCORE
# *SZPositiveSymptoms has cohort:SNUH
# *SZPositiveSymptoms has cohort:SaoPaulo
# *SZPositiveSymptoms has cohort:TOP
# *SZPositiveSymptoms has cohort:UMCU
# *SZPositiveSymptoms has cohort:UMCUS
# *SZPositiveSymptoms has cohort:UNIBA
# *SZPositiveSymptoms has cohort:UPENN
# *SZWorkingGroup has cohort:AMC
# *SZWorkingGroup has cohort:ASRB
# *SZWorkingGroup has cohort:CAMH
# *SZWorkingGroup has cohort:CIAM
# *SZWorkingGroup has cohort:CLING
# *SZWorkingGroup has cohort:COBRE
# *SZWorkingGroup has cohort:DublinDonohoe
# *SZWorkingGroup has cohort:ESO
# *SZWorkingGroup has cohort:EdinburghEHRS
# *SZWorkingGroup has cohort:EdinburghFunc
# *SZWorkingGroup has cohort:EdinburghSFMH
# *SZWorkingGroup has cohort:FBIRN
# *SZWorkingGroup has cohort:FIDMAG
# *SZWorkingGroup has cohort:FOR2107
# *SZWorkingGroup has cohort:Frankfurt
# *SZWorkingGroup has cohort:GAP
# *SZWorkingGroup has cohort:GIPSI
# *SZWorkingGroup has cohort:Galway
# *SZWorkingGroup has cohort:HMS
# *SZWorkingGroup has cohort:HUBIN
# *SZWorkingGroup has cohort:Huilong2
# *SZWorkingGroup has cohort:Indiana
# *SZWorkingGroup has cohort:JHU
# *SZWorkingGroup has cohort:KASP
# *SZWorkingGroup has cohort:MADRID
# *SZWorkingGroup has cohort:NU
# *SZWorkingGroup has cohort:OLIN
# *SZWorkingGroup has cohort:OsakaMR1
# *SZWorkingGroup has cohort:OsakaMR2
# *SZWorkingGroup has cohort:Oxford
# *SZWorkingGroup has cohort:PAFIP1.5T
# *SZWorkingGroup has cohort:PAFIP3T
# *SZWorkingGroup has cohort:RSCZ
# *SZWorkingGroup has cohort:RomeSL
# *SZWorkingGroup has cohort:SNUH
# *SZWorkingGroup has cohort:SaoPaulo
# *SZWorkingGroup has cohort:TOP
# *SZWorkingGroup has cohort:UCIZSZ
# *SZWorkingGroup has cohort:UMCU
# *SZWorkingGroup has cohort:UMCUS
# *SZWorkingGroup has cohort:UNIBA
# *SZWorkingGroup has cohort:UNICAMP
# *SZWorkingGroup has cohort:UNIMAAS
# *SZWorkingGroup has cohort:UPENN

# %% [markdown]
# This queries shows us all the cohorts which have results available.

# %%
#Which Cohorts have results available?
url = "http://linkedearth.isi.edu:3030/db"
replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"

query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT distinct ?w
WHERE 
{
    # ?w wiki:Property-3AHasProjectResults ?a.
}"""


response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

#print(res)
print("Cohorts with results available:")    
for item in res['results']['bindings']:
     print ("*" + item['w']['value'].replace(replace,""))
# Out:
# Cohorts with results available:
# *Test_Cohort
# *1000BRAINS_ENIGMA3_Cortical_GWAS
# *ADNI1_ENIGMA3_Cortical_GWAS
# *ADNI2GO_ENIGMA3_Cortical_GWAS
# *ALSPACa_ENIGMA3_Cortical_GWAS
# *ASRB_ENIGMA3_Cortical_GWAS
# *BETULA_ENIGMA3_Cortical_GWAS
# *BIG-2DAffy_ENIGMA3_Cortical_GWAS
# *BIG-2DPsychChip_ENIGMA3_Cortical_GWAS
# *BONN_ENIGMA3_Cortical_GWAS
# *BrainScale_ENIGMA3_Cortical_GWAS
# *CARDIFF_ENIGMA3_Cortical_GWAS
# *DNS-2DV3_ENIGMA3_Cortical_GWAS
# *DNS-2DV4_ENIGMA3_Cortical_GWAS
# *EPIGEN_ENIGMA3_Cortical_GWAS
# *FBIRN_ENIGMA3_Cortical_GWAS
# *FOR2107_ENIGMA3_Cortical_GWAS
# *GIG_ENIGMA3_Cortical_GWAS
# *GOBS_ENIGMA3_Cortical_GWAS
# *GSP_ENIGMA3_Cortical_GWAS
# *HUBIN_ENIGMA3_Cortical_GWAS
# *HUNT_ENIGMA3_Cortical_GWAS
# *IMAGEN_ENIGMA3_Cortical_GWAS
# *IMH_ENIGMA3_Cortical_GWAS
# *IMpACT_ENIGMA3_Cortical_GWAS
# *LBC1936_ENIGMA3_Cortical_GWAS
# *LIBD_ENIGMA3_Cortical_GWAS
# *MCIC_ENIGMA3_Cortical_GWAS
# *Meth-2DCT_ENIGMA3_Cortical_GWAS
# *MIRECC_ENIGMA3_Cortical_GWAS
# *MooDS_ENIGMA3_Cortical_GWAS
# *MPIP_ENIGMA3_Cortical_GWAS
# *MPRC_ENIGMA3_Cortical_GWAS
# *MUNSTER_ENIGMA3_Cortical_GWAS
# *NCNG_ENIGMA3_Cortical_GWAS
# *NESDA_ENIGMA3_Cortical_GWAS
# *NeuroIMAGE_ENIGMA3_Cortical_GWAS
# *NTR_ENIGMA3_Cortical_GWAS
# *OATS_ENIGMA3_Cortical_GWAS
# *OSAKA_ENIGMA3_Cortical_GWAS
# *PAFIP_ENIGMA3_Cortical_GWAS
# *PDNZ_ENIGMA3_Cortical_GWAS
# *PING_ENIGMA3_Cortical_GWAS
# *PING-2DnonEUR_ENIGMA3_Cortical_GWAS
# *PPMI_ENIGMA3_Cortical_GWAS
# *QTIM_ENIGMA3_Cortical_GWAS
# *SHIP_ENIGMA3_Cortical_GWAS
# *SHIP-2DTrend_ENIGMA3_Cortical_GWAS
# *Sydney_MAS_ENIGMA3_Cortical_GWAS
# *SYS_ENIGMA3_Cortical_GWAS
# *TCD-2DNUIG_ENIGMA3_Cortical_GWAS
# *TOP_ENIGMA3_Cortical_GWAS
# *TOP3T_ENIGMA3_Cortical_GWAS
# *UiO2016_ENIGMA3_Cortical_GWAS
# *UiO2017_ENIGMA3_Cortical_GWAS
# *UKBB_ENIGMA3_Cortical_GWAS
# *UKBB-2DnonEUR_ENIGMA3_Cortical_GWAS
# *UMCU_ENIGMA3_Cortical_GWAS
# *UNICAMP_ENIGMA3_Cortical_GWAS
# *1000BRAINS_prj_ENIGMA3_Cortical_GWAS
# *ADNI1_prj_ENIGMA3_Cortical_GWAS
# *ADNI2GO_prj_ENIGMA3_Cortical_GWAS
# *ALSPACa_prj_ENIGMA3_Cortical_GWAS
# *ASRB_prj_ENIGMA3_Cortical_GWAS
# *BETULA_prj_ENIGMA3_Cortical_GWAS
# *BIG-2DAffy_prj_ENIGMA3_Cortical_GWAS
# *BIG-2DPsychChip_prj_ENIGMA3_Cortical_GWAS
# *BONN_prj_ENIGMA3_Cortical_GWAS
# *BrainScale_prj_ENIGMA3_Cortical_GWAS
# *CARDIFF_prj_ENIGMA3_Cortical_GWAS
# *DNS-2DV3_prj_ENIGMA3_Cortical_GWAS
# *DNS-2DV4_prj_ENIGMA3_Cortical_GWAS
# *EPIGEN_prj_ENIGMA3_Cortical_GWAS
# *FBIRN_prj_ENIGMA3_Cortical_GWAS
# *FOR2107_prj_ENIGMA3_Cortical_GWAS
# *GIG_prj_ENIGMA3_Cortical_GWAS
# *GOBS_prj_ENIGMA3_Cortical_GWAS
# *GSP_prj_ENIGMA3_Cortical_GWAS
# *HUBIN_prj_ENIGMA3_Cortical_GWAS
# *HUNT_prj_ENIGMA3_Cortical_GWAS
# *IMAGEN_prj_ENIGMA3_Cortical_GWAS
# *IMH_prj_ENIGMA3_Cortical_GWAS
# *IMpACT_prj_ENIGMA3_Cortical_GWAS
# *LBC1936_prj_ENIGMA3_Cortical_GWAS
# *LIBD_prj_ENIGMA3_Cortical_GWAS
# *MCIC_prj_ENIGMA3_Cortical_GWAS
# *Meth-2DCT_prj_ENIGMA3_Cortical_GWAS
# *MIRECC_prj_ENIGMA3_Cortical_GWAS
# *MooDS_prj_ENIGMA3_Cortical_GWAS
# *MPIP_prj_ENIGMA3_Cortical_GWAS
# *MPRC_prj_ENIGMA3_Cortical_GWAS
# *MUNSTER_prj_ENIGMA3_Cortical_GWAS
# *NCNG_prj_ENIGMA3_Cortical_GWAS
# *NESDA_prj_ENIGMA3_Cortical_GWAS
# *NeuroIMAGE_prj_ENIGMA3_Cortical_GWAS
# *NTR_prj_ENIGMA3_Cortical_GWAS
# *OATS_prj_ENIGMA3_Cortical_GWAS
# *OSAKA_prj_ENIGMA3_Cortical_GWAS
# *PAFIP_prj_ENIGMA3_Cortical_GWAS
# *PDNZ_prj_ENIGMA3_Cortical_GWAS
# *PING-2DnonEUR_prj_ENIGMA3_Cortical_GWAS
# *PING_prj_ENIGMA3_Cortical_GWAS
# *PPMI_prj_ENIGMA3_Cortical_GWAS
# *QTIM_prj_ENIGMA3_Cortical_GWAS
# *SHIP_prj_ENIGMA3_Cortical_GWAS
# *SHIP-2DTrend_prj_ENIGMA3_Cortical_GWAS
# *Sydney_MAS_prj_ENIGMA3_Cortical_GWAS
# *SYS_prj_ENIGMA3_Cortical_GWAS
# *TCD-2DNUIG_prj_ENIGMA3_Cortical_GWAS
# *TOP_prj_ENIGMA3_Cortical_GWAS
# *TOP3T_prj_ENIGMA3_Cortical_GWAS
# *UiO2016_prj_ENIGMA3_Cortical_GWAS
# *UiO2017_prj_ENIGMA3_Cortical_GWAS
# *UKBB-2DnonEUR_prj_ENIGMA3_Cortical_GWAS
# *UKBB_prj_ENIGMA3_Cortical_GWAS
# *UMCU_prj_ENIGMA3_Cortical_GWAS
# *UNICAMP_prj_ENIGMA3_Cortical_GWAS

# %% [markdown]
# The next query shows us all the projects which belong to the SZ (Schizophrenia) Working group along with the number of participants in each project.

# %%
#What is the number of participants in each project within the SZ working group?
url = "http://linkedearth.isi.edu:3030/db"
replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"

query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?c ?num
WHERE 
{
    # ?w wiki:Property-3AHasName_Short_-28E-29 "SZ".
    # ?w wiki:Property-3AHasCohort_-28E-29 ?c.
    # ?c wiki:Property-3AHasNumberOfParticipants_-28E-29 ?num.
}"""


response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

print("Number of participants in cohorts associated with SZ Working Group:")    
for item in res['results']['bindings']:
     print ("*" + item['c']['value'].replace(replace,"")+" has number of participants: " + item['num']['value'].replace(replace,""))
# Out:
# Number of participants in cohorts associated with SZ Working Group:
# *AMC has number of participants: 376
# *CAMH has number of participants: 264
# *CIAM has number of participants: 51
# *CLING has number of participants: 372
# *COBRE has number of participants: 198
# *DublinDonohoe has number of participants: 284
# *EdinburghEHRS has number of participants: 67
# *EdinburghFunc has number of participants: 60
# *EdinburghSFMH has number of participants: 76
# *ESO has number of participants: 80
# *FIDMAG has number of participants: 283
# *Frankfurt has number of participants: 59
# *GAP has number of participants: 233
# *GIPSI has number of participants: 55
# *Huilong2 has number of participants: 140
# *KASP has number of participants: 65
# *NU has number of participants: 200
# *OLIN has number of participants: 770
# *OsakaMR1 has number of participants: 529
# *OsakaMR2 has number of participants: 341
# *PAFIP1.5T has number of participants: 229
# *RomeSL has number of participants: 561
# *RSCZ has number of participants: 127
# *SaoPaulo has number of participants: 153
# *SNUH has number of participants: 139
# *UMCUS has number of participants: 190

# %% [markdown]
# This query allows us to identify the cohorts which have participants within the age range 20 - 40.

# %%
#Which Cohorts have patients in the age range (20 - 40)
url = "http://linkedearth.isi.edu:3030/db"
replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"

query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT distinct ?cohort ?minage ?maxage
WHERE 
{
    # ?cohort wiki:Property-3AHasAge_Minimum_-28E-29 ?minage.
    # ?cohort wiki:Property-3AHasAge_Maximum_-28E-29 ?maxage.
    FILTER (?minage >= "20" && ?maxage <= "40")
}
"""


response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

#print(res)
print("Cohorts with patients between the age range 20-40:")
for item in res['results']['bindings']:
     print ("*" + item['cohort']['value'].replace(replace,""))
# Out:
# Cohorts with patients between the age range 20-40:
# *NeuroIMAGE_prj_ENIGMA3_Cortical_GWAS
# *PING_prj_ENIGMA3_Cortical_GWAS
# *BrainScale_prj_ENIGMA3_Cortical_GWAS
# *ID1000_Replication_Cohort_prj_ENIGMA3_Cortical_GWAS
# *CHARGE_Replication_Cohort_prj_ENIGMA3_Cortical_GWAS
# *PING-2DnonEUR_prj_ENIGMA3_Cortical_GWAS

# %% [markdown]
# The following tells us which cohorts are associated with specific brain scan datatypes.

# %%
#Which cohorts have data corresponding to brain scan data-types?
url = "http://linkedearth.isi.edu:3030/db"
replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"

query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT distinct ?cohort ?data
WHERE 
{
    # ?cohort wiki:Property-3AHasBrainScanDataType_-28E-29 ?data.
}
"""

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)

#print(res)
print("Cohorts with T1w data:")    
for item in res['results']['bindings']:
     print ("*" + item['cohort']['value'].replace(replace,"") + " has datatype: " + item['data']['value'].replace(replace,""))
# Out:
# Cohorts with T1w data:
# *CLING has datatype: T1-2DweightedMRI
# *Frankfurt has datatype: T1-2DweightedMRI
# *ENIGMA3_Cortical_GWAS has datatype: T1-2Dweighted_MRI
# *DLBS_over60yrs has datatype: Amyloid_PET
# *DLBS_under60yrs has datatype: Amyloid_PET
# *ASRB has datatype: T1w
# *FBIRN has datatype: T1w
# *FOR2107 has datatype: T1w
# *Galway has datatype: T1w
# *HMS has datatype: T1w
# *HUBIN has datatype: T1w
# *KaSP has datatype: T1w
# *MCIC has datatype: T1w
# *TOP has datatype: T1w
# *UMCU has datatype: T1w
# *UNIBA has datatype: T1w
# *UPENN has datatype: T1w
# *UNICAMP has datatype: T1w
# *MPIP has datatype: T1w
# *EPIGEN has datatype: T1w
# *BETULA has datatype: T1w
# *IMpACT has datatype: T1w
# *NeuroIMAGE has datatype: T1w
# *BONN has datatype: T1w
# *GIG has datatype: T1w
# *GOBS has datatype: T1w
# *GSP has datatype: T1w
# *HUNT has datatype: T1w
# *IMAGEN has datatype: T1w
# *IMH has datatype: T1w
# *LBC1936 has datatype: T1w
# *LIBD has datatype: T1w
# *OATS has datatype: T1w
# *Meth-2DCT has datatype: T1w
# *MUNSTER has datatype: T1w
# *NCNG has datatype: T1w
# *NESDA has datatype: T1w
# *PAFIP has datatype: T1w
# *PING has datatype: T1w
# *QTIM has datatype: T1w
# *SHIP has datatype: T1w
# *SYS has datatype: T1w
# *TOP3T has datatype: T1w
# *DLBS_over60yrs has datatype: T1w
# *DLBS_under60yrs has datatype: T1w
# *ADNI1 has datatype: T1w
# *ADNI2 has datatype: T1w
# *UKBB_under50yrs has datatype: T1w
# *UKBB_50to55yrs has datatype: T1w
# *UKBB_55to60yrs has datatype: T1w
# *UKBB_60to65yrs has datatype: T1w
# *UKBB_65to70yrs has datatype: T1w
# *UKBB_over70yrs has datatype: T1w
# *AIBL has datatype: T1w
# *1000BRAINS has datatype: T1w
# *ADNI2GO has datatype: T1w
# *ALSPACa has datatype: T1w
# *BIG-2DAffy has datatype: T1w
# *BIG-2DPsychChip has datatype: T1w
# *BrainScale has datatype: T1w
# *CARDIFF has datatype: T1w
# *DNS-2DV3 has datatype: T1w
# *DNS-2DV4 has datatype: T1w
# *MIRECC has datatype: T1w
# *MooDS has datatype: T1w
# *MPRC has datatype: T1w
# *NTR has datatype: T1w
# *OSAKA has datatype: T1w
# *PDNZ has datatype: T1w
# *PING-2DnonEUR has datatype: T1w
# *PPMI has datatype: T1w
# *SHIP-2DTrend has datatype: T1w
# *Sydney_MAS has datatype: T1w
# *TCD-2DNUIG has datatype: T1w
# *UiO2016 has datatype: T1w
# *UiO2017 has datatype: T1w
# *UKBB has datatype: T1w
# *UKBB-2DnonEUR has datatype: T1w
# *ID1000_Replication_Cohort has datatype: T1w
# *CHARGE_Replication_Cohort has datatype: T1w
# *UKBB-2DPRS has datatype: T1w
# *Positive_Symptoms has datatype: T1w
# *Edinburgh_-28SFMH-29 has datatype: T1w
# *FBIRN_-28Phase3-29 has datatype: T1w
# *ROMA_S.Lucia has datatype: T1w
# *UMCU_SOMMER has datatype: T1w
# *Dublin has datatype: T1w
# *ClinG_Positive_Symptoms has datatype: T1w
# *HMS_Positive_Symptoms has datatype: T1w
# *Dublin_Positive_Symptoms has datatype: T1w
# *Edinburgh_-28SFMH-29_Positive_Symptoms has datatype: T1w
# *FBIRN_-28Phase3-29_Positive_Symptoms has datatype: T1w
# *Galway_Positive_Symptoms has datatype: T1w
# *HUBIN_Positive_Symptoms has datatype: T1w
# *KaSP_Positive_Symptoms has datatype: T1w
# *PAFIP_Positive_Symptoms has datatype: T1w
# *TOP_Positive_Symptoms has datatype: T1w
# *UMCU_Positive_Symptoms has datatype: T1w
# *UPENN_Positive_Symptoms has datatype: T1w
# *MCIC_Positive_Symptoms has datatype: T1w
# *ROMA_S.Lucia_Positive_Symptoms has datatype: T1w
# *OSAKA_Positive_Symptoms has datatype: T1w
# *UMCU_SOMMER_Positive_Symptoms has datatype: T1w
# *UNIBA_Positive_Symptoms has datatype: T1w
# *CliNG_Positive_Symptoms has datatype: T1w
# *CliNG has datatype: T1w
# *1000BRAINS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ADNI1_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ADNI2GO_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ALSPACa_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ASRB_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BETULA_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BIG-2DAffy_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BIG-2DPsychChip_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BONN_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BrainScale_ENIGMA3_Cortical_GWAS has datatype: T1w
# *CARDIFF_ENIGMA3_Cortical_GWAS has datatype: T1w
# *DNS-2DV3_ENIGMA3_Cortical_GWAS has datatype: T1w
# *DNS-2DV4_ENIGMA3_Cortical_GWAS has datatype: T1w
# *EPIGEN_ENIGMA3_Cortical_GWAS has datatype: T1w
# *FBIRN_ENIGMA3_Cortical_GWAS has datatype: T1w
# *FOR2107_ENIGMA3_Cortical_GWAS has datatype: T1w
# *GIG_ENIGMA3_Cortical_GWAS has datatype: T1w
# *GOBS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *GSP_ENIGMA3_Cortical_GWAS has datatype: T1w
# *HUBIN_ENIGMA3_Cortical_GWAS has datatype: T1w
# *HUNT_ENIGMA3_Cortical_GWAS has datatype: T1w
# *IMAGEN_ENIGMA3_Cortical_GWAS has datatype: T1w
# *IMH_ENIGMA3_Cortical_GWAS has datatype: T1w
# *IMpACT_ENIGMA3_Cortical_GWAS has datatype: T1w
# *LBC1936_ENIGMA3_Cortical_GWAS has datatype: T1w
# *LIBD_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MCIC_ENIGMA3_Cortical_GWAS has datatype: T1w
# *Meth-2DCT_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MIRECC_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MooDS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MPIP_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MPRC_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MUNSTER_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NCNG_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NESDA_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NeuroIMAGE_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NTR_ENIGMA3_Cortical_GWAS has datatype: T1w
# *OATS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *OSAKA_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PAFIP_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PDNZ_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PING_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PING-2DnonEUR_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PPMI_ENIGMA3_Cortical_GWAS has datatype: T1w
# *QTIM_ENIGMA3_Cortical_GWAS has datatype: T1w
# *SHIP_ENIGMA3_Cortical_GWAS has datatype: T1w
# *SHIP-2DTrend_ENIGMA3_Cortical_GWAS has datatype: T1w
# *Sydney_MAS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *SYS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *TCD-2DNUIG_ENIGMA3_Cortical_GWAS has datatype: T1w
# *TOP_ENIGMA3_Cortical_GWAS has datatype: T1w
# *TOP3T_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UiO2016_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UiO2017_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UKBB_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UKBB-2DnonEUR_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UMCU_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UNICAMP_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ID1000_Replication_Cohort_ENIGMA3_Cortical_GWAS has datatype: T1w
# *CHARGE_Replication_Cohort_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UKBB-2DPRS_ENIGMA3_Cortical_GWAS has datatype: T1w
# *CliNG_proj_NegativeSymptoms_SCZ has datatype: T1w
# *Proj_Subcortical has datatype: T1w
# *Proj_Cortical has datatype: T1w
# *Proj_Negative_Symptoms has datatype: T1w
# *Proj_Positive_Symptoms has datatype: T1w
# *Proj_Aggression has datatype: T1w
# *Proj_Laterality_Subcortical has datatype: T1w
# *Proj_Relatives has datatype: T1w
# *Proj_GWAS_Enigma_3 has datatype: T1w
# *Proj_Harmonization_-28ComBAT-29 has datatype: T1w
# *CLiNG has datatype: T1w
# *CLiNG_grp_HC_proj_Cortical_SCZ has datatype: T1w
# *CLiNG_grp_SCZ_proj_Cortical_SCZ has datatype: T1w
# *CLiNG_proj_Subcortical_SCZ has datatype: T1w
# *CLiNG_proj_Cortical_SCZ has datatype: T1w
# *CLiNG_grp_HC has datatype: T1w
# *CLiNG_grp_SCZ has datatype: T1w
# *Dublin_proj_Subcortical_SCZ has datatype: T1w
# *Dublin_proj_Cortical_SCZ has datatype: T1w
# *Dublin_grp_HC has datatype: T1w
# *Dublin_grp_SCZ has datatype: T1w
# *1000BRAINS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ADNI1_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ADNI2GO_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ALSPACa_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ASRB_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BETULA_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BIG-2DAffy_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BIG-2DPsychChip_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BONN_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *BrainScale_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *CARDIFF_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *DNS-2DV3_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *DNS-2DV4_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *EPIGEN_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *FBIRN_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *FOR2107_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *GIG_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *GOBS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *GSP_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *HUBIN_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *HUNT_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *IMAGEN_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *IMH_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *IMpACT_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *LBC1936_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *LIBD_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MCIC_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *Meth-2DCT_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MIRECC_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MooDS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MPIP_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MPRC_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *MUNSTER_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NCNG_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NESDA_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NeuroIMAGE_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *NTR_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *OATS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *OSAKA_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PAFIP_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PDNZ_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PING_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PING-2DnonEUR_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *PPMI_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *QTIM_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *SHIP_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *SHIP-2DTrend_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *Sydney_MAS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *SYS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *TCD-2DNUIG_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *TOP_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *TOP3T_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UiO2016_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UiO2017_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UKBB_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UKBB-2DnonEUR_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UMCU_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UNICAMP_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *ID1000_Replication_Cohort_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *CHARGE_Replication_Cohort_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *UKBB-2DPRS_prj_ENIGMA3_Cortical_GWAS has datatype: T1w
# *AMC_proj_Cortical_SCZ has datatype: T1w
# *AMC_proj_Subcortical_SCZ has datatype: T1w
# *ASRB_proj_Cortical_SCZ has datatype: T1w
# *Basel_SCORE_proj_SubcorticalShape_SCZ has datatype: T1w
# *CAIM_proj_SubcorticalShape_SCZ has datatype: T1w
# *CAMH_proj_Cortical_SCZ has datatype: T1w
# *CAMH_proj_SubcorticalShape_SCZ has datatype: T1w
# *CIAM_proj_Cortical_SCZ has datatype: T1w
# *CliNG_proj_PositiveSymptoms_SCZ has datatype: T1w
# *COBRE_proj_Cortical_SCZ has datatype: T1w
# *Dublin_proj_NegativeSymptoms_SCZ has datatype: T1w
# *Dublin_proj_PositiveSymptoms_SCZ has datatype: T1w
# *Dublin_proj_SubcorticalShape_SCZ has datatype: T1w
# *Edinburgh_-28SFMH-29_proj_NegativeSymptoms_SCZ has datatype: T1w
# *Edinburgh_-28SFMH-29_proj_PositiveSymptoms_SCZ has datatype: T1w
# *Edinburgh_proj_Subcortical_SCZ has datatype: T1w
# *EdinburghEHRS_proj_Cortical_SCZ has datatype: T1w
# *EdinburghFunc_proj_Cortical_SCZ has datatype: T1w
# *EdinburghSFMH_proj_Cortical_SCZ has datatype: T1w
# *ESO_proj_Cortical_SCZ has datatype: T1w
# *FBIRN_-28Phase3-29_proj_NegativeSymptoms_SCZ has datatype: T1w
# *FBIRN_-28Phase3-29_proj_PositiveSymptoms_SCZ has datatype: T1w
# *FBIRN_proj_Cortical_SCZ has datatype: T1w
# *FBIRN_proj_Subcortical_SCZ has datatype: T1w
# *FBIRN_proj_SubcorticalShape_SCZ has datatype: T1w
# *FIDMAG_proj_Cortical_SCZ has datatype: T1w
# *FIDMAG_proj_SubcorticalShape_SCZ has datatype: T1w
# *Frankfurt_proj_Cortical_SCZ has datatype: T1w
# *Galway_proj_Cortical_SCZ has datatype: T1w
# *Galway_proj_NegativeSymptoms_SCZ has datatype: T1w
# *Galway_proj_PositiveSymptoms_SCZ has datatype: T1w
# *Galway_proj_Subcortical_SCZ has datatype: T1w
# *Galway_proj_SubcorticalShape_SCZ has datatype: T1w
# *GAP_proj_Cortical_SCZ has datatype: T1w
# *HMS_proj_Cortical_SCZ has datatype: T1w
# *HMS_proj_NegativeSymptoms_SCZ has datatype: T1w
# *HMS_proj_PositiveSymptoms_SCZ has datatype: T1w
# *HMS_proj_Subcortical_SCZ has datatype: T1w
# *HUBIN_proj_Cortical_SCZ has datatype: T1w
# *HUBIN_proj_NegativeSymptoms_SCZ has datatype: T1w
# *HUBIN_proj_PositiveSymptoms_SCZ has datatype: T1w
# *HUBIN_proj_Subcortical_SCZ has datatype: T1w
# *Hubin_proj_SubcorticalShape_SCZ has datatype: T1w
# *Huilong1_proj_Cortical_SCZ has datatype: T1w
# *Huilong2_proj_Cortical_SCZ has datatype: T1w
# *Indiana_proj_SubcorticalShape_SCZ has datatype: T1w
# *KaSP_proj_Cortical_SCZ has datatype: T1w
# *KaSP_proj_NegativeSymptoms_SCZ has datatype: T1w
# *KaSP_proj_PositiveSymptoms_SCZ has datatype: T1w
# *KASP_proj_SubcorticalShape_SCZ has datatype: T1w
# *MCIC_proj_Cortical_SCZ has datatype: T1w
# *MCIC_proj_NegativeSymptoms_SCZ has datatype: T1w
# *MCIC_proj_PositiveSymptoms_SCZ has datatype: T1w
# *MCIC_proj_Subcortical_SCZ has datatype: T1w
# *MCIC_proj_SubcorticalShape_SCZ has datatype: T1w
# *MPRC_proj_SubcorticalShape_SCZ has datatype: T1w
# *MPRC1_proj_Cortical_SCZ has datatype: T1w
# *MPRC2_proj_Cortical_SCZ has datatype: T1w
# *NARSAD_proj_SubcorticalShape_SCZ has datatype: T1w
# *NU_proj_Cortical_SCZ has datatype: T1w
# *NU_proj_Subcortical_SCZ has datatype: T1w
# *NU_proj_SubcorticalShape_SCZ has datatype: T1w
# *OLIN_proj_Cortical_SCZ has datatype: T1w
# *Olin_proj_Subcortical_SCZ has datatype: T1w
# *Olin_proj_SubcorticalShape_SCZ has datatype: T1w
# *Osaka_proj_Cortical_SCZ has datatype: T1w
# *OSAKA_proj_NegativeSymptoms_SCZ has datatype: T1w
# *OSAKA_proj_PositiveSymptoms_SCZ has datatype: T1w
# *Oxford_proj_SubcorticalShape_SCZ has datatype: T1w
# *PAFIP_GE_proj_SubcorticalShape_SCZ has datatype: T1w
# *PAFIP_proj_NegativeSymptoms_SCZ has datatype: T1w
# *PAFIP_proj_PositiveSymptoms_SCZ has datatype: T1w
# *PAFIP_proj_Subcortical_SCZ has datatype: T1w
# *PAFIP1.5T_proj_Cortical_SCZ has datatype: T1w
# *PAFIP3T_proj_Cortical_SCZ has datatype: T1w
# *R_SCZ_proj_SubcorticalShape_SCZ has datatype: T1w
# *RAFIP_Phil_proj_SubcorticalShape_SCZ has datatype: T1w
# *ROMA_S.Lucia_proj_NegativeSymptoms_SCZ has datatype: T1w
# *ROMA_S.Lucia_proj_PositiveSymptoms_SCZ has datatype: T1w
# *RomeSL_proj_Cortical_SCZ has datatype: T1w
# *RSCZ_proj_Cortical_SCZ has datatype: T1w
# *SaoPaulo_proj_Cortical_SCZ has datatype: T1w
# *SCORE_proj_Cortical_SCZ has datatype: T1w
# *SLF_Rome_proj_SubcorticalShape_SCZ has datatype: T1w
# *SNUH_proj_Cortical_SCZ has datatype: T1w
# *TOP_proj_Cortical_SCZ has datatype: T1w
# *TOP_proj_NegativeSymptoms_SCZ has datatype: T1w
# *TOP_proj_PositiveSymptoms_SCZ has datatype: T1w
# *TOP_proj_Subcortical_SCZ has datatype: T1w
# *TOP_proj_SubcorticalShape_SCZ has datatype: T1w
# *UCISZ_proj_SubcorticalShape_SCZ has datatype: T1w
# *UMCU_proj_Cortical_SCZ has datatype: T1w
# *UMCU_proj_NegativeSymptoms_SCZ has datatype: T1w
# *UMCU_proj_PositiveSymptoms_SCZ has datatype: T1w
# *UMCU_proj_Subcortical_SCZ has datatype: T1w
# *UMCU_SOMMER_proj_NegativeSymptoms_SCZ has datatype: T1w
# *UMCU_SOMMER_proj_PositiveSymptoms_SCZ has datatype: T1w
# *UMCUS_proj_Cortical_SCZ has datatype: T1w
# *UNIBA_proj_Cortical_SCZ has datatype: T1w
# *UNIBA_proj_NegativeSymptoms_SCZ has datatype: T1w
# *UNIBA_proj_PositiveSymptoms_SCZ has datatype: T1w
# *UPENN_proj_Cortical_SCZ has datatype: T1w
# *UPENN_proj_NegativeSymptoms_SCZ has datatype: T1w
# *UPENN_proj_PositiveSymptoms_SCZ has datatype: T1w
# *UPENN_proj_Subcortical_SCZ has datatype: T1w
# *UPenn_proj_SubcorticalShape_SCZ has datatype: T1w
# *Wellcome_proj_SubcorticalShape_SCZ has datatype: T1w
# *DLBS_over60yrs has datatype: DTI
# *DLBS_under60yrs has datatype: DTI
# *DLBS_over60yrs has datatype: FMRI
# *DLBS_under60yrs has datatype: FMRI
# *DLBS_over60yrs has datatype: RsfMRI
# *DLBS_under60yrs has datatype: RsfMRI
# *ADNI1 has datatype: DWI
# *ADNI2 has datatype: DWI
# *UKBB_under50yrs has datatype: DWI
# *UKBB_50to55yrs has datatype: DWI
# *UKBB_55to60yrs has datatype: DWI
# *UKBB_60to65yrs has datatype: DWI
# *UKBB_65to70yrs has datatype: DWI
# *UKBB_over70yrs has datatype: DWI
# *AIBL has datatype: DWI
# *Proj_DTI has datatype: DWI
# *Proj_DTI_IQ has datatype: DWI

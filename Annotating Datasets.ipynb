# %% [markdown]
# This notebook can be used to annotate the GWAS datasets on the ENIGMA wiki with the values for attributes such as Brain Region, SNP and Trait. These annotations are useful to test the hypothesis "Effect Size of Genotype on BrainImagingTrait of ROI is associated with Demographic" on the DISK portal.

# %%
import json
import requests
import pandas as pd

# %%
#Obtaining the content URLs for GWAS data downloads

replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"
query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX enigma: <https://w3id.org/enigma#>
SELECT ?gwasproject ?projresults ?url
WHERE 
{
    # ?gwasproject wiki:Property-3AName_-28E-29 "GWAS".
    # ?gwasproject wiki:Property-3AHasCohort_-28E-29 ?cohort.
    # ?cohort wiki:Property-3AHasCohortProject_-28E-29 ?cohortproject.
    # ?cohortproject wiki:Property-3AHasProjectResults ?projresults.
    # ?projresults wiki:Property-3AHasContentUrl_-28E-29 ?url
}
"""

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)
# print(res)

query_results=[]
print("Data Downloads:")    
for item in res['results']['bindings']:
    a1 = item['projresults']['value'].replace(replace,"")
    w1 = item['url']['value'].replace(replace,"")
    query_results.append([a1,w1])

df = pd.DataFrame(query_results)
df.columns=['Data Download','Content URL']
df.head(20)
# Out:
# Data Downloads:
#                                Data Download  \
# 0         ASRB_ENIGMA3_Cortical_GWAS_Results
# 1        FBIRN_ENIGMA3_Cortical_GWAS_Results
# 2      FOR2107_ENIGMA3_Cortical_GWAS_Results
# 3        HUBIN_ENIGMA3_Cortical_GWAS_Results
# 4         MCIC_ENIGMA3_Cortical_GWAS_Results
# 5          TOP_ENIGMA3_Cortical_GWAS_Results
# 6         UMCU_ENIGMA3_Cortical_GWAS_Results
# 7      UNICAMP_ENIGMA3_Cortical_GWAS_Results
# 8         MPIP_ENIGMA3_Cortical_GWAS_Results
# 9       EPIGEN_ENIGMA3_Cortical_GWAS_Results
# 10      IMpACT_ENIGMA3_Cortical_GWAS_Results
# 11  NeuroIMAGE_ENIGMA3_Cortical_GWAS_Results
# 12        GOBS_ENIGMA3_Cortical_GWAS_Results
# 13         GSP_ENIGMA3_Cortical_GWAS_Results
# 14        HUNT_ENIGMA3_Cortical_GWAS_Results
# 15      IMAGEN_ENIGMA3_Cortical_GWAS_Results
# 16         IMH_ENIGMA3_Cortical_GWAS_Results
# 17     LBC1936_ENIGMA3_Cortical_GWAS_Results
# 18        LIBD_ENIGMA3_Cortical_GWAS_Results
# 19        OATS_ENIGMA3_Cortical_GWAS_Results
#
#                                           Content URL
# 0   http://organicdatacuration.org/enigma_new/imag...
# 1   http://organicdatacuration.org/enigma_new/imag...
# 2   http://organicdatacuration.org/enigma_new/imag...
# 3   http://organicdatacuration.org/enigma_new/imag...
# 4   http://organicdatacuration.org/enigma_new/imag...
# 5   http://organicdatacuration.org/enigma_new/imag...
# 6   http://organicdatacuration.org/enigma_new/imag...
# 7   http://organicdatacuration.org/enigma_new/imag...
# 8   http://organicdatacuration.org/enigma_new/imag...
# 9   http://organicdatacuration.org/enigma_new/imag...
# 10  http://organicdatacuration.org/enigma_new/imag...
# 11  http://organicdatacuration.org/enigma_new/imag...
# 12  http://organicdatacuration.org/enigma_new/imag...
# 13  http://organicdatacuration.org/enigma_new/imag...
# 14  http://organicdatacuration.org/enigma_new/imag...
# 15  http://organicdatacuration.org/enigma_new/imag...
# 16  http://organicdatacuration.org/enigma_new/imag...
# 17  http://organicdatacuration.org/enigma_new/imag...
# 18  http://organicdatacuration.org/enigma_new/imag...
# 19  http://organicdatacuration.org/enigma_new/imag...

# %%
##This function identifies and returns the values a dataset containts for Area, Trait and SNP
def get_annotations(test):
    csv = pd.read_csv(test)
    df2 = pd.DataFrame(csv)
    area = set()
    trait = set()
    snp = set()
    for a in df2['AREA']:
        area.add(a)
    for t in df2['TRAIT']:
        trait.add(t)
    for s in df2['SNP']:
        snp.add(s)
    return area, trait, snp

# %%
##Logging into wiki

S = requests.Session()

URL = "http://organicdatacuration.org/enigma_new/api.php"

# Retrieve login token
PARAMS_0 = {
    'action':"query",
    'meta':"tokens",
    'type':"login",
    'format':"json"
}

DATA = S.get(url=URL, params=PARAMS_0).json()
LOGIN_TOKEN = DATA['query']['tokens']['logintoken']

print("Login Token: ",LOGIN_TOKEN)

# Go to http://organicdatacuration.org/enigma_new/index.php/Special:BotPasswords for lgname & lgpassword, and add them below

PARAMS_1 = {
    'action':"login",
    'lgname':"",
    'lgpassword':"",
    'lgtoken':LOGIN_TOKEN,
    'format':"json"
}

DATA = S.post(URL, data=PARAMS_1).json()

print(DATA)

# %%
##Test Annotation

idx = 2
test_title = df['Data Download'][idx]
url = df['Content URL'][idx]
print(url)
area1, trait1, snp1 = get_annotations(url)
traits = "|Trait=".join(trait1)
areas = "|BrainRegion=".join(area1)
snps = "|SNP=".join(snp1)
text_to_append="{{#set:|BrainRegion="+areas+"}}\n"+"{{#set:|Trait="+traits+"}}\n"+"{{#set:|SNP="+snps+"}}"
print(test_title)

PARAMS_2 = {
        "action": "query",
        "meta": "tokens",
        "format": "json"
    }

R = S.get(url=URL, params=PARAMS_2)
DATA = R.json()

CSRF_TOKEN = DATA['query']['tokens']['csrftoken']

# Step 4: POST request to edit a page

PARAMS_EDIT = {
    "action": "edit",
    "title": test_title,
    "section": "new",
    "format": "json",
    "text": text_to_append,
    "token": CSRF_TOKEN,
}

R = S.post(URL, data=PARAMS_EDIT)
DATA = R.json()

print(DATA)
# Out:
# http://organicdatacuration.org/enigma_new/images/a/a7/FOR2107_Significant_GWAS.csv
# FOR2107_ENIGMA3_Cortical_GWAS_Results
# {'edit': {'result': 'Success', 'pageid': 12732, 'title': 'FOR2107 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28553, 'newrevid': 28554, 'newtimestamp': '2020-11-18T17:59:40Z'}}

# %%
##Annotating all the datasets

for idx, row in df.iterrows():
    test_title = df['Data Download'][idx]
    url = df['Content URL'][idx]
    area1, trait1, snp1 = get_annotations(url)
    traits = "|Trait=".join(trait1)
    areas = "|BrainRegion=".join(area1)
    snps = "|SNP=".join(snp1)
    text_to_append="{{#set:|BrainRegion="+areas+"}}\n"+"{{#set:|Trait="+traits+"}}\n"+"{{#set:|SNP="+snps+"}}"

    PARAMS_2 = {
            "action": "query",
            "meta": "tokens",
            "format": "json"
        }

    R = S.get(url=URL, params=PARAMS_2)
    DATA = R.json()

    CSRF_TOKEN = DATA['query']['tokens']['csrftoken']

    # Step 4: POST request to edit a page

    PARAMS_EDIT = {
        "action": "edit",
        "title": test_title,
        "section": "new",
        "format": "json",
        "text": text_to_append,
        "token": CSRF_TOKEN,
    }

    R = S.post(URL, data=PARAMS_EDIT)
    DATA = R.json()

    print(DATA)
# Out:
# {'edit': {'result': 'Success', 'pageid': 12666, 'title': 'ASRB ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28436, 'newrevid': 28555, 'newtimestamp': '2020-11-18T18:07:12Z'}}
# {'edit': {'result': 'Success', 'pageid': 12729, 'title': 'FBIRN ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28519, 'newrevid': 28556, 'newtimestamp': '2020-11-18T18:07:13Z'}}
# {'edit': {'result': 'Success', 'pageid': 12732, 'title': 'FOR2107 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28554, 'newrevid': 28557, 'newtimestamp': '2020-11-18T18:07:14Z'}}
# {'edit': {'result': 'Success', 'pageid': 12740, 'title': 'HUBIN ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28452, 'newrevid': 28558, 'newtimestamp': '2020-11-18T18:07:15Z'}}
# {'edit': {'result': 'Success', 'pageid': 12754, 'title': 'MCIC ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28459, 'newrevid': 28559, 'newtimestamp': '2020-11-18T18:07:16Z'}}
# {'edit': {'result': 'Success', 'pageid': 12802, 'title': 'TOP ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28483, 'newrevid': 28560, 'newtimestamp': '2020-11-18T18:07:17Z'}}
# {'edit': {'result': 'Success', 'pageid': 12814, 'title': 'UMCU ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28489, 'newrevid': 28561, 'newtimestamp': '2020-11-18T18:07:17Z'}}
# {'edit': {'result': 'Success', 'pageid': 12816, 'title': 'UNICAMP ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28490, 'newrevid': 28562, 'newtimestamp': '2020-11-18T18:07:18Z'}}
# {'edit': {'result': 'Success', 'pageid': 12762, 'title': 'MPIP ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28463, 'newrevid': 28563, 'newtimestamp': '2020-11-18T18:07:19Z'}}
# {'edit': {'result': 'Success', 'pageid': 12727, 'title': 'EPIGEN ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28446, 'newrevid': 28564, 'newtimestamp': '2020-11-18T18:07:20Z'}}
# {'edit': {'result': 'Success', 'pageid': 12748, 'title': 'IMpACT ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28456, 'newrevid': 28565, 'newtimestamp': '2020-11-18T18:07:21Z'}}
# {'edit': {'result': 'Success', 'pageid': 12772, 'title': 'NeuroIMAGE ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28468, 'newrevid': 28566, 'newtimestamp': '2020-11-18T18:07:22Z'}}
# {'edit': {'result': 'Success', 'pageid': 12736, 'title': 'GOBS ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28450, 'newrevid': 28567, 'newtimestamp': '2020-11-18T18:07:22Z'}}
# {'edit': {'result': 'Success', 'pageid': 12738, 'title': 'GSP ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28451, 'newrevid': 28568, 'newtimestamp': '2020-11-18T18:07:23Z'}}
# {'edit': {'result': 'Success', 'pageid': 12742, 'title': 'HUNT ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28453, 'newrevid': 28569, 'newtimestamp': '2020-11-18T18:07:24Z'}}
# {'edit': {'result': 'Success', 'pageid': 12744, 'title': 'IMAGEN ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28454, 'newrevid': 28570, 'newtimestamp': '2020-11-18T18:07:25Z'}}
# {'edit': {'result': 'Success', 'pageid': 12746, 'title': 'IMH ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28455, 'newrevid': 28571, 'newtimestamp': '2020-11-18T18:07:26Z'}}
# {'edit': {'result': 'Success', 'pageid': 12750, 'title': 'LBC1936 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28457, 'newrevid': 28572, 'newtimestamp': '2020-11-18T18:07:26Z'}}
# {'edit': {'result': 'Success', 'pageid': 12752, 'title': 'LIBD ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28458, 'newrevid': 28573, 'newtimestamp': '2020-11-18T18:07:27Z'}}
# {'edit': {'result': 'Success', 'pageid': 12776, 'title': 'OATS ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28470, 'newrevid': 28574, 'newtimestamp': '2020-11-18T18:07:28Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13251, 'title': 'Meth-2DCT ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28575, 'newtimestamp': '2020-11-18T18:07:29Z'}}
# {'edit': {'result': 'Success', 'pageid': 12766, 'title': 'MUNSTER ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28465, 'newrevid': 28576, 'newtimestamp': '2020-11-18T18:07:30Z'}}
# {'edit': {'result': 'Success', 'pageid': 12768, 'title': 'NCNG ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28466, 'newrevid': 28577, 'newtimestamp': '2020-11-18T18:07:31Z'}}
# {'edit': {'result': 'Success', 'pageid': 12770, 'title': 'NESDA ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28467, 'newrevid': 28578, 'newtimestamp': '2020-11-18T18:07:31Z'}}
# {'edit': {'result': 'Success', 'pageid': 12780, 'title': 'PAFIP ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28472, 'newrevid': 28579, 'newtimestamp': '2020-11-18T18:07:32Z'}}
# {'edit': {'result': 'Success', 'pageid': 12786, 'title': 'PING ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28474, 'newrevid': 28580, 'newtimestamp': '2020-11-18T18:07:33Z'}}
# {'edit': {'result': 'Success', 'pageid': 12790, 'title': 'QTIM ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28477, 'newrevid': 28581, 'newtimestamp': '2020-11-18T18:07:34Z'}}
# {'edit': {'result': 'Success', 'pageid': 12792, 'title': 'SHIP ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28478, 'newrevid': 28582, 'newtimestamp': '2020-11-18T18:07:35Z'}}
# {'edit': {'result': 'Success', 'pageid': 12798, 'title': 'SYS ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28481, 'newrevid': 28583, 'newtimestamp': '2020-11-18T18:07:36Z'}}
# {'edit': {'result': 'Success', 'pageid': 12804, 'title': 'TOP3T ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28484, 'newrevid': 28584, 'newtimestamp': '2020-11-18T18:07:36Z'}}
# {'edit': {'result': 'Success', 'pageid': 12818, 'title': 'ADNI1 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28433, 'newrevid': 28585, 'newtimestamp': '2020-11-18T18:07:37Z'}}
# {'edit': {'result': 'Success', 'pageid': 12658, 'title': '1000BRAINS ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28432, 'newrevid': 28586, 'newtimestamp': '2020-11-18T18:07:38Z'}}
# {'edit': {'result': 'Success', 'pageid': 12662, 'title': 'ADNI2GO ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28434, 'newrevid': 28587, 'newtimestamp': '2020-11-18T18:07:38Z'}}
# {'edit': {'result': 'Success', 'pageid': 12664, 'title': 'ALSPACa ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28435, 'newrevid': 28588, 'newtimestamp': '2020-11-18T18:07:39Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13252, 'title': 'BIG-2DAffy ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28589, 'newtimestamp': '2020-11-18T18:07:40Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13253, 'title': 'BIG-2DPsychChip ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28590, 'newtimestamp': '2020-11-18T18:07:41Z'}}
# {'edit': {'result': 'Success', 'pageid': 12719, 'title': 'BrainScale ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28442, 'newrevid': 28591, 'newtimestamp': '2020-11-18T18:07:42Z'}}
# {'edit': {'result': 'Success', 'pageid': 12722, 'title': 'CARDIFF ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28443, 'newrevid': 28592, 'newtimestamp': '2020-11-18T18:07:42Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13254, 'title': 'DNS-2DV3 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28593, 'newtimestamp': '2020-11-18T18:07:43Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13255, 'title': 'DNS-2DV4 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28594, 'newtimestamp': '2020-11-18T18:07:44Z'}}
# {'edit': {'result': 'Success', 'pageid': 12758, 'title': 'MIRECC ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28461, 'newrevid': 28595, 'newtimestamp': '2020-11-18T18:07:45Z'}}
# {'edit': {'result': 'Success', 'pageid': 12760, 'title': 'MooDS ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28462, 'newrevid': 28596, 'newtimestamp': '2020-11-18T18:07:46Z'}}
# {'edit': {'result': 'Success', 'pageid': 12764, 'title': 'MPRC ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28464, 'newrevid': 28597, 'newtimestamp': '2020-11-18T18:07:47Z'}}
# {'edit': {'result': 'Success', 'pageid': 12774, 'title': 'NTR ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28469, 'newrevid': 28598, 'newtimestamp': '2020-11-18T18:07:48Z'}}
# {'edit': {'result': 'Success', 'pageid': 12778, 'title': 'OSAKA ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28471, 'newrevid': 28599, 'newtimestamp': '2020-11-18T18:07:48Z'}}
# {'edit': {'result': 'Success', 'pageid': 12782, 'title': 'PDNZ ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28473, 'newrevid': 28600, 'newtimestamp': '2020-11-18T18:07:49Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13256, 'title': 'PING-2DnonEUR ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28601, 'newtimestamp': '2020-11-18T18:07:50Z'}}
# {'edit': {'result': 'Success', 'pageid': 12788, 'title': 'PPMI ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28476, 'newrevid': 28602, 'newtimestamp': '2020-11-18T18:07:51Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13257, 'title': 'SHIP-2DTrend ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28603, 'newtimestamp': '2020-11-18T18:07:52Z'}}
# {'edit': {'result': 'Success', 'pageid': 12796, 'title': 'Sydney MAS ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28480, 'newrevid': 28604, 'newtimestamp': '2020-11-18T18:07:53Z'}}
# {'edit': {'new': '', 'result': 'Success', 'pageid': 13258, 'title': 'TCD-2DNUIG ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 0, 'newrevid': 28605, 'newtimestamp': '2020-11-18T18:07:53Z'}}
# {'edit': {'result': 'Success', 'pageid': 12806, 'title': 'UiO2016 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28485, 'newrevid': 28606, 'newtimestamp': '2020-11-18T18:07:54Z'}}
# {'edit': {'result': 'Success', 'pageid': 12808, 'title': 'UiO2017 ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28486, 'newrevid': 28607, 'newtimestamp': '2020-11-18T18:07:55Z'}}
# {'edit': {'result': 'Success', 'pageid': 12812, 'title': 'UKBB ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28487, 'newrevid': 28608, 'newtimestamp': '2020-11-18T18:07:56Z'}}
# {'edit': {'result': 'Success', 'pageid': 13244, 'title': 'UKBB-2DnonEUR ENIGMA3 Cortical GWAS Results', 'contentmodel': 'wikitext', 'oldrevid': 28497, 'newrevid': 28609, 'newtimestamp': '2020-11-18T18:07:57Z'}}

# %%
##Testing query to extract dataset based on property Trait = "TH"

replace = "http://localhost:8080/enigma_new/index.php/Special:URIResolver/"
url = ""
query = """PREFIX wiki: <http://localhost:8080/enigma_new/index.php/Special:URIResolver/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX enigma: <https://w3id.org/enigma#>
SELECT ?d
WHERE 
{
    # ?d a wiki:Category-3ADataDownload_-28E-29.
    # ?d wiki:Property-3ATrait "TH".
}
"""

response = requests.post(url, data = {'query': query})
res = json.loads(response.text)
print(res)

query_results=[]
print("Data Downloads:")    
for item in res['results']['bindings']:
    a1 = item['d']['value'].replace(replace,"")
    query_results.append([a1])

dfresult = pd.DataFrame(query_results)
dfresult.columns=['Data Download']
dfresult
# Out:
# {'head': {'vars': ['d']}, 'results': {'bindings': [{'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/1000BRAINS_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/ADNI1_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/ADNI2GO_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/ALSPACa_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/ASRB_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/BrainScale_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/CARDIFF_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/EPIGEN_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/FBIRN_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/FOR2107_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/GOBS_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/GSP_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/HUBIN_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/HUNT_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/IMAGEN_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/IMH_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/IMpACT_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/LBC1936_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/LIBD_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/MCIC_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/MIRECC_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/MooDS_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/MPIP_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/MPRC_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/MUNSTER_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/NCNG_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/NESDA_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/NeuroIMAGE_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'uri', 'value': 'http://localhost:8080/enigma_new/index.php/Special:URIResolver/NTR_ENIGMA3_Cortical_GWAS_Results'}}, {'d': {'type': 'u ...
# Data Downloads:
#                                Data Download
# 0   1000BRAINS_ENIGMA3_Cortical_GWAS_Results
# 1        ADNI1_ENIGMA3_Cortical_GWAS_Results
# 2      ADNI2GO_ENIGMA3_Cortical_GWAS_Results
# 3      ALSPACa_ENIGMA3_Cortical_GWAS_Results
# 4         ASRB_ENIGMA3_Cortical_GWAS_Results
# 5   BrainScale_ENIGMA3_Cortical_GWAS_Results
# 6      CARDIFF_ENIGMA3_Cortical_GWAS_Results
# 7       EPIGEN_ENIGMA3_Cortical_GWAS_Results
# 8        FBIRN_ENIGMA3_Cortical_GWAS_Results
# 9      FOR2107_ENIGMA3_Cortical_GWAS_Results
# 10        GOBS_ENIGMA3_Cortical_GWAS_Results
# 11         GSP_ENIGMA3_Cortical_GWAS_Results
# 12       HUBIN_ENIGMA3_Cortical_GWAS_Results
# 13        HUNT_ENIGMA3_Cortical_GWAS_Results
# 14      IMAGEN_ENIGMA3_Cortical_GWAS_Results
# 15         IMH_ENIGMA3_Cortical_GWAS_Results
# 16      IMpACT_ENIGMA3_Cortical_GWAS_Results
# 17     LBC1936_ENIGMA3_Cortical_GWAS_Results
# 18        LIBD_ENIGMA3_Cortical_GWAS_Results
# 19        MCIC_ENIGMA3_Cortical_GWAS_Results
# 20      MIRECC_ENIGMA3_Cortical_GWAS_Results
# 21       MooDS_ENIGMA3_Cortical_GWAS_Results
# 22        MPIP_ENIGMA3_Cortical_GWAS_Results
# 23        MPRC_ENIGMA3_Cortical_GWAS_Results
# 24     MUNSTER_ENIGMA3_Cortical_GWAS_Results
# 25        NCNG_ENIGMA3_Cortical_GWAS_Results
# 26       NESDA_ENIGMA3_Cortical_GWAS_Results
# 27  NeuroIMAGE_ENIGMA3_Cortical_GWAS_Results
# 28         NTR_ENIGMA3_Cortical_GWAS_Results
# 29        OATS_ENIGMA3_Cortical_GWAS_Results
# 30       OSAKA_ENIGMA3_Cortical_GWAS_Results
# 31       PAFIP_ENIGMA3_Cortical_GWAS_Results
# 32        PDNZ_ENIGMA3_Cortical_GWAS_Results
# 33        PING_ENIGMA3_Cortical_GWAS_Results
# 34        PPMI_ENIGMA3_Cortical_GWAS_Results
# 35        QTIM_ENIGMA3_Cortical_GWAS_Results
# 36        SHIP_ENIGMA3_Cortical_GWAS_Results
# 37  Sydney_MAS_ENIGMA3_Cortical_GWAS_Results
# 38         SYS_ENIGMA3_Cortical_GWAS_Results
# 39         TOP_ENIGMA3_Cortical_GWAS_Results
# 40       TOP3T_ENIGMA3_Cortical_GWAS_Results
# 41     UiO2016_ENIGMA3_Cortical_GWAS_Results
# 42     UiO2017_ENIGMA3_Cortical_GWAS_Results
# 43        UKBB_ENIGMA3_Cortical_GWAS_Results
# 44        UMCU_ENIGMA3_Cortical_GWAS_Results
# 45     UNICAMP_ENIGMA3_Cortical_GWAS_Results
